# %% [markdown]
# # Refinement Architecture: added BusVsAll model
#
# **Rational**
# Deal with confusion between dependent concepts such as _train_ and _subway_ activities depicted in the following confusion matrix
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
import stjohns as ag
# Out:
# #################################################
# updated @12:58 (june 18) version of stjohns_7.py:
# + updated hyperparameters with best so-far -- arch#184 (SaFpz) gave 66.54% on validation (tehran_1)
# + used only Pressure, *_m modalities
# #################################################
# updated @16:38 (june 18) version of stjohns_8.py:
# + models' weights are saved every epoch
# + dropout after each layer (even after Conv1d)
# + switched back to 25 epochs
# #################################################
# updated @18:15 (june 18) version of stjohns_9.py:
# + switched back to dropout only after dense layers (not after Conv1d)
# #################################################
# updated @20:44 (june 18) version of stjohns_10.py:
# + reduce dropout for dense layers (view_Position) from ~0.8 to ~0.5 but keep the last dropout is kept @0.8
# + as val_acc is above tr_acc, increase number of epochs from 25 to 50
# #################################################
# updated @15:55 (june 19) version of stjohns_11.py:
# + discard pressure modality from training set (only Magnitude data)
# #################################################
# updated @15:58 (june 20) version of stjohns_12.py:
# + stillVsAll model with `new_classes`
# + data is loaded from RefinedSample id='stillVsAll'
# + using Magnitude data and Pressure
# #################################################
# updated @18:48 (june 20) version of stjohns_13.py:
# + forgot to put 2 for num_classes in the call to tf.keras.utils.to_categorical() AND ALSO in the output of the upermost dense layer
# + given that the labels in refinedsample start from 0, no need to -1 in the call to load_data()
# #################################################
# updated @23:11 (june 20) version of stjohns_14.py:
# + carVsBus
# #################################################
# updated @00:26 (june 21) version of stjohns_15.py:
# + trainVsSubway
# #################################################
# updated @01:25 (june 21) version of stjohns_16.py:
# + groupedActivities (Bus with Car and Train with Subway)
# + now, num_classes in to_categorical() and the output of the upermost dense layer are set to 5
# #################################################
# updated @18:20 (june 21) version of refinementArchitecture.ipynb:
# + made num_classes not hard-coded in order to ease refinementArchitecture
# #################################################
# updated @00:41 (june 22) version of stjohns_17.py:
# + back to the original classes to test fft data
# + using fft_new data
# + so now, fft_new only without magnitude nor pressure
# #################################################
# updated @10:24 (june 22) version of stjohns_18.py:
# + trainVsSubway
# + Reworking this model which was really bad initialy
# + Added a 3rd Conv1d/MaxPool/BatchNorm block
# + back to 0.2 in configuration
# + using magnitude + pressure data as used initially
# #################################################
# updated @12:02 (june 22) version of stjohns_19.py:
# + back to only 1 Conv1d/MaxPool/BatchNorm block
# + still using magnitude and pressure data
# #################################################
# updated @12:43 (june 22) version of stjohns_20.py:
# + carVsBus
# + Reworking this model which was really bad initialy
# + back to only 1 Conv1d/MaxPool/BatchNorm block
# + still using magnitude and pressure data
# #################################################
# updated @13:18 (june 22) version of stjohns_21.py:
# + carVsBus
# + reduce learning rate from 1e04 to 1e05
# #################################################
# updated @14:00 (june 22) version of stjohns_22.py:
# + trainVsSubway
# + using pressure + acc_m + mag_m
# + back to a learning rate of 1e04
# #################################################
# updated @14:25 (june 22) version of stjohns_23.py:
# + trainVsSubway
# + using (Acc/Mag)_(x/y/z)_fft_new + pressure + (Acc/Mag)_m
# #################################################
# updated @16:44 (june 22) version of stjohns_24.py:
# + stillVsAll
# + Reworking this model which was really bad initialy
# + back to only 1 Conv1d/MaxPool/BatchNorm block
# + still using magnitude and pressure data
# #################################################
# updated @18:24 (june 22) version of stjohns_25.py:
# + groupedActivities (Bus with Car and Train with Subway)
# + Reworking this model which was really bad initialy
# + back to only 1 Conv1d/MaxPool/BatchNorm block
# + still using magnitude and pressure data
# #################################################
# updated @22:30 (june 22) version of stjohns_26.py:
# + busVsAll

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  4

# %% [markdown]
# ### Loading models

# %%
# StillVsAll model (initial:stjohns_13, current:stjohns_24)
checkpoint_path = 'stjohns_24'
epoch = 50

#map original labels to the new learning problem
new_classes = {
    0: ['still'],
    1: ['walk', 'run', 'bike', 'car', 'bus', 'train', 'subway']
}
num_classes = len(list(new_classes.keys()))

StillVsAll = ag.stjohns(ag.dict_of_params(ag.params), num_classes=num_classes)
StillVsAll.load_weights(checkpoint_path+'/cp.{epoch:04d}.ckpt'.format(epoch=epoch))
# Out:
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m

# %%
# GroupedActivities model (initial:stjohns_16, current:stjohns_25)
checkpoint_path = 'stjohns_25'
epoch = 50

#map original labels to the new learning problem
new_classes = {
    0: ['walk'],
    1: ['run'],
    2: ['bike'],
    3: ['car', 'bus'],
    4: ['train', 'subway']
}
num_classes = len(list(new_classes.keys()))

groupedActivities = ag.stjohns(ag.dict_of_params(ag.params), num_classes=num_classes)
groupedActivities.load_weights(checkpoint_path+'/cp.{epoch:04d}.ckpt'.format(epoch=epoch))
# Out:
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m

# %%
# BusVsCar model (initial:stjohns_14, current:stjohns_20)
checkpoint_path = 'stjohns_20'
epoch = 40

#map original labels to the new learning problem
new_classes = {
    0: ['car'],
    1: ['bus']
}
num_classes = len(list(new_classes.keys()))

carVsBus = ag.stjohns(ag.dict_of_params(ag.params), num_classes=num_classes)
carVsBus.load_weights(checkpoint_path+'/cp.{epoch:04d}.ckpt'.format(epoch=epoch))
# Out:
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m

# %%
# TrainVsSubway model (initial:stjohns_15, current:stjohns_19)
checkpoint_path = 'stjohns_19'
epoch = 30

#map original labels to the new learning problem
new_classes = {
    0: ['train'],
    1: ['subway']
}
num_classes = len(list(new_classes.keys()))

trainVsSubway = ag.stjohns(ag.dict_of_params(ag.params), num_classes=num_classes)
trainVsSubway.load_weights(checkpoint_path+'/cp.{epoch:04d}.ckpt'.format(epoch=epoch))
# Out:
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m

# %%
# BusVsAll model (stjohns_26)
checkpoint_path = 'stjohns_26'
epoch = 10

#map original labels to the new learning problem
new_classes = {
    0: ['bus'],
    1: ['walk', 'run', 'bike', 'car', 'train', 'subway']
}
num_classes = len(list(new_classes.keys()))

busVsAll = ag.stjohns(ag.dict_of_params(ag.params), num_classes=num_classes)
busVsAll.load_weights(checkpoint_path+'/cp.{epoch:04d}.ckpt'.format(epoch=epoch))
# Out:
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m
# circuit of channel Pressure
# circuit of channel Acc_m
# circuit of channel Gyr_m
# circuit of channel Mag_m
# circuit of channel Ori_m
# circuit of channel Gra_m
# circuit of channel LAcc_m

# %% [markdown]
# ### Refinment Predictions

# %%
valid_dict, valid_labels = ag.load_data(what='validation', refinedSampleId=None)
# Out:
# generated/0.2/validation/validation_Torso_Pressure.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_Acc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_Gyr_m.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_Mag_m.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_Ori_m.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_Gra_m.mmap exists, loading ...
# generated/0.2/validation/validation_Torso_LAcc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Pressure.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Acc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Gyr_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Mag_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Ori_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_Gra_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hips_LAcc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Pressure.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Acc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Gyr_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Mag_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Ori_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_Gra_m.mmap exists, loading ...
# generated/0.2/validation/validation_Bag_LAcc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Pressure.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Acc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Gyr_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Mag_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Ori_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_Gra_m.mmap exists, loading ...
# generated/0.2/validation/validation_Hand_LAcc_m.mmap exists, loading ...
# generated/0.2/validation/validation_Label.mmap exists, loading ...

# %%
print(valid_dict['Hips_Acc_m'].shape)
print(valid_labels.shape)
# Out:
# (28789, 500)
# (28789,)

# %%
# make predictions
import numpy as np
from dataset import DataReader
import time


#y_pred = np.asarray(model.predict(valid_dict, verbose=1))
#y_true = valid_labels
#y_pred_class = np.argmax(y_pred, axis=1)

y_true = valid_labels
y_pred_class = np.zeros_like(y_true) - 1

# print((valid_dict['Torso_Acc_m'][0])[np.newaxis, :].shape)


start_time = time.time()
for i, label in enumerate(y_true):
    if i % 100 == 0:
        print(i)
    example = {
        pos+'_'+m: (valid_dict[pos+'_'+m][i])[np.newaxis, :]
        for m in DataReader.channels.values()
        for pos in DataReader.smartphone_positions
    }
    
    y_pred = StillVsAll.predict(example)
    pred_class = np.argmax(y_pred, axis=1)
    
    if pred_class == 0:  # still
        #print('still')
        y_pred_class[i] = DataReader.inv_coarselabel_map['still']
        
    else:  # other
        y_pred = busVsAll.predict(example)
        pred_class = np.argmax(y_pred, axis=1)
        
        if pred_class == 0:  # bus
            #print('bus')
            y_pred_class[i] = DataReader.inv_coarselabel_map['bus']
        
        else:  # other
            y_pred = groupedActivities.predict(example)
            pred_class = np.argmax(y_pred, axis=1)
            
            if pred_class == 0:  # walk
                #print('walk')
                y_pred_class[i] = DataReader.inv_coarselabel_map['walk']
            elif pred_class == 1:  # run
                #print('run')
                y_pred_class[i] = DataReader.inv_coarselabel_map['run']
            elif pred_class == 2:  # bike
                #print('bike')
                y_pred_class[i] = DataReader.inv_coarselabel_map['bike']
            elif pred_class == 3:  # car-bus
                y_pred = carVsBus.predict(example)
                pred_class = np.argmax(y_pred, axis=1)
                
                if pred_class == 0:  # car
                    #print('car')
                    y_pred_class[i] = DataReader.inv_coarselabel_map['car']
                else:  # bus
                    print('2nd bus branch')
                    print('predictions : {}'.format(y_pred))
                    y_pred_class[i] = DataReader.inv_coarselabel_map['bus']
            else:  # train-subway
                y_pred = trainVsSubway.predict(example)
                pred_class = np.argmax(y_pred, axis=1)
                
                if pred_class == 0:  # train
                    #print('train')
                    y_pred_class[i] = DataReader.inv_coarselabel_map['train']
                else:  # subway
                    #print('subway')
                    y_pred_class[i] = DataReader.inv_coarselabel_map['subway']
                
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0
# 2nd bus branch
# predictions : [[8.660135e-04 9.991340e-01]]
# 2nd bus branch
# predictions : [[0.0021156  0.99788433]]
# 100
# 2nd bus branch
# predictions : [[0.00666751 0.99333245]]
# 200
# 2nd bus branch
# predictions : [[0.00687683 0.99312323]]
# 2nd bus branch
# predictions : [[0.07097289 0.92902714]]
# 300
# 400
# 2nd bus branch
# predictions : [[0.00517025 0.9948297 ]]
# 2nd bus branch
# predictions : [[0.00271629 0.9972837 ]]
# 2nd bus branch
# predictions : [[0.00454417 0.99545586]]
# 2nd bus branch
# predictions : [[0.01165845 0.9883415 ]]
# 2nd bus branch
# predictions : [[0.02695499 0.973045  ]]
# 2nd bus branch
# predictions : [[0.00303084 0.99696916]]
# 2nd bus branch
# predictions : [[0.00351939 0.99648064]]
# 2nd bus branch
# predictions : [[0.00423737 0.99576265]]
# 2nd bus branch
# predictions : [[8.1201916e-04 9.9918801e-01]]
# 2nd bus branch
# predictions : [[0.01663439 0.9833656 ]]
# 2nd bus branch
# predictions : [[0.025395   0.97460496]]
# 2nd bus branch
# predictions : [[0.01861919 0.9813809 ]]
# 2nd bus branch
# predictions : [[0.24883266 0.75116736]]
# 500
# 2nd bus branch
# predictions : [[0.00238926 0.9976107 ]]
# 2nd bus branch
# predictions : [[0.00187547 0.99812454]]
# 2nd bus branch
# predictions : [[5.3628406e-04 9.9946374e-01]]
# 600
# 700
# 2nd bus branch
# predictions : [[0.00189709 0.9981029 ]]
# 2nd bus branch
# predictions : [[0.016565 0.983435]]
# 2nd bus branch
# predictions : [[0.43017077 0.5698292 ]]
# 2nd bus branch
# predictions : [[0.08817348 0.91182655]]
# 2nd bus branch
# predictions : [[0.02235726 0.9776428 ]]
# 800
# 2nd bus branch
# predictions : [[0.01567073 0.98432934]]
# 2nd bus branch
# predictions : [[0.03615842 0.96384156]]
# 2nd bus branch
# predictions : [[0.14265408 0.85734594]]
# 2nd bus branch
# predictions : [[0.01608447 0.9839155 ]]
# 2nd bus branch
# predictions : [[0.07422727 0.9257727 ]]
# 900
# 2nd bus branch
# predictions : [[0.00881443 0.9911856 ]]
# 2nd bus branch
# predictions : [[0.06567454 0.9343255 ]]
# 2nd bus branch
# predictions : [[0.01345769 0.98654234]]
# 2nd bus branch
# predictions : [[0.02530455 0.97469544]]
# 2nd bus branch
# predictions : [[0.00996297 0.9900371 ]]
# 2nd bus branch
# predictions : [[1.1208854e-04 9.9988794e-01]]
# 1000
# 2nd bus branch
# predictions : [[0.0036871 0.9963129]]
# 2nd bus branch
# predictions : [[1.4779915e-04 9.9985218e-01]]
# 2nd bus branch
# predictions : [[0.00105559 0.99894446]]
# 2nd bus branch
# predictions : [[7.4609084e-04 9.9925393e-01]]
# 2nd bus branch
# predictions : [[0.00407118 0.9959288 ]]
# 2nd bus branch
# predictions : [[0.00571472 0.9942853 ]]
# 2nd bus branch
# predictions : [[0.05983774 0.94016224]]
# 2nd bus branch
# predictions : [[0.0021806 0.9978194]]
# 2nd bus branch
# predictions : [[0.07340527 0.9265947 ]]
# 1100
# 2nd bus branch
# predictions : [[0.10213321 0.8978668 ]]
# 2nd bus branch
# predictions : [[0.06849562 0.9315044 ]]
# 2nd bus branch
# predictions : [[0.02234189 0.97765815]]
# 2nd bus branch
# predictions : [[0.01170198 0.988298  ]]
# 2nd bus branch
# predictions : [[0.02755806 0.9724419 ]]
# 2nd bus branch
# predictions : [[0.02503787 0.9749621 ]]
# 2nd bus branch
# predictions : [[0.32343492 0.6765651 ]]
# 1200
# 2nd bus branch
# predictions : [[0.00941148 0.99058855]]
# 2nd bus branch
# predictions : [[0.01343124 0.9865688 ]]
# 1300
# 2nd bus branch
# predictions : [[4.4337584e-04 9.9955660e-01]]
# 2nd bus branch
# predictions : [[0.00969627 0.9903037 ]]
# 2nd bus branch
# predictions : [[0.01497493 0.985025  ]]
# 2nd bus branch
# predictions : [[0.00500898 0.994991  ]]
# 2nd bus branch
# predictions : [[0.48448762 0.51551235]]
# 2nd bus branch
# predictions : [[0.01498303 0.98501694]]
# 2nd bus branch
# predictions : [[0.00210763 0.99789244]]
# 2nd bus branch
# predictions : [[0.0209227 0.9790773]]
# 2nd bus branch
# predictions : [[0.35258213 0.6474179 ]]
# 2nd bus branch
# predictions : [[0.13955806 0.860442  ]]
# 2nd bus branch
# predictions : [[0.2614068  0.73859316]]
# 2nd bus branch
# predictions : [[0.06696551 0.9330345 ]]
# 2nd bus branch
# predictions : [[0.12502424 0.8749758 ]]
# 2nd bus branch
# predictions : [[0.04431083 0.9556892 ]]
# 2nd bus branch
# predictions : [[0.03520014 0.9647999 ]]
# 2nd bus branch
# predictions : [[0.07074413 0.92925584]]
# 2nd bus branch
# predictions : [[0.06733452 0.9326655 ]]
# 2nd bus branch
# predictions : [[0.09659139 0.90340865]]
# 2nd bus branch
# predictions : [[0.19934675 0.8006533 ]]
# 2nd bus branch
# predictions : [[0.14235806 0.85764194]]
# 2nd bus branch
# predictions : [[0.0042719 0.9957281]]
# 2nd bus branch
# predictions : [[0.16585794 0.834142  ]]
# 2nd bus branch
# predictions : [[0.42632324 0.57367676]]
# 2nd bus branch
# predictions : [[0.01319317 0.9868068 ]]
# 2nd bus branch
# predictions : [[0.02753113 0.9724689 ]]
# 2nd bus branch
# predictions : [[0.01556322 0.98443675]]
# 2nd bus branch
# predictions : [[0.06419191 0.93580806]]
# 2nd bus branch
# predictions : [[0.00508099 0.994919  ]]
# 2nd bus branch
# predictions : [[2.2260431e-04 9.9977738e-01]]
# 1400
# 2nd bus branch
# predictions : [[0.00140983 0.9985902 ]]
# 2nd bus branch
# predictions : [[0.14312956 0.8568704 ]]
# 2nd bus branch
# predictions : [[0.00357716 0.9964228 ]]
# 2nd bus branch
# predictions : [[6.719931e-04 9.993280e-01]]
# 2nd bus branch
# predictions : [[0.00387432 0.99612564]]
# 2nd bus branch
# predictions : [[0.00375967 0.9962404 ]]
# 2nd bus branch
# predictions : [[4.491420e-04 9.995509e-01]]
# 2nd bus branch
# predictions : [[0.0114406 0.9885594]]
# 2nd bus branch
# predictions : [[0.00921444 0.9907856 ]]
# 2nd bus branch
# predictions : [[0.01060811 0.9893919 ]]
# 2nd bus branch
# predictions : [[0.00203782 0.99796224]]
# 2nd bus branch
# predictions : [[0.0016533 0.9983467]]
# 2nd bus branch
# predictions : [[0.01296166 0.9870384 ]]
# 2nd bus branch
# predictions : [[0.06760555 0.9323944 ]]
# 1500
# 2nd bus branch
# predictions : [[0.0293952 0.9706048]]
# 2nd bus branch
# predictions : [[0.10215548 0.8978445 ]]
# 2nd bus branch
# predictions : [[0.00405323 0.9959468 ]]
# 2nd bus branch
# predictions : [[0.0163397  0.98366034]]
# 2nd bus branch
# predictions : [[0.00262618 0.9973738 ]]
# 2nd bus branch
# predictions : [[0.01012547 0.9898746 ]]
# 2nd bus branch
# predictions : [[0.00510596 0.994894  ]]
# 2nd bus branch
# predictions : [[0.054593   0.94540703]]
# 2nd bus branch
# predictions : [[8.2936342e-05 9.9991703e-01]]
# 2nd bus branch
# predictions : [[0.00326133 0.99673873]]
# 2nd bus branch
# predictions : [[0.00317829 0.99682176]]
# 2nd bus branch
# predictions : [[0.00685473 0.9931452 ]]
# 2nd bus branch
# predictions : [[0.00578778 0.9942122 ]]
# 2nd bus branch
# predictions : [[0.00570593 0.9942941 ]]
# 2nd bus branch
# predictions : [[0.02212694 0.9778731 ]]
# 2nd bus branch
# predictions : [[1.7250558e-04 9.9982750e-01]]
# 2nd bus branch
# predictions : [[6.337665e-04 9.993662e-01]]
# 2nd bus branch
# predictions : [[0.00328804 0.99671197]]
# 2nd bus branch
# predictions : [[0.07458918 0.92541075]]
# 2nd bus branch
# predictions : [[0.06074295 0.939257  ]]
# 2nd bus branch
# predictions : [[0.00860966 0.99139035]]
# 2nd bus branch
# predictions : [[0.4129878  0.58701223]]
# 2nd bus branch
# predictions : [[0.33838853 0.6616115 ]]
# 2nd bus branch
# predictions : [[0.01307801 0.986922  ]]
# 2nd bus branch
# predictions : [[0.00748441 0.9925156 ]]
# 2nd bus branch
# predictions : [[0.370049 0.629951]]
# 2nd bus branch
# predictions : [[0.00846517 0.9915348 ]]
# 2nd bus branch
# predictions : [[0.02733358 0.97266644]]
# 2nd bus branch
# predictions : [[0.02103816 0.97896177]]
# 2nd bus branch
# predictions : [[0.4155705 0.5844295]]
# 2nd bus branch
# predictions : [[0.00420424 0.9957957 ]]
# 2nd bus branch
# predictions : [[0.09888916 0.90111077]]
# 2nd bus branch
# predictions : [[0.30284417 0.69715583]]
# 2nd bus branch
# predictions : [[0.05125767 0.94874233]]
# 2nd bus branch
# predictions : [[0.08431968 0.91568035]]
# 1600
# 2nd bus branch
# predictions : [[0.04933016 0.9506698 ]]
# 2nd bus branch
# predictions : [[0.00537895 0.99462104]]
# 2nd bus branch
# predictions : [[0.0922512  0.90774876]]
# 2nd bus branch
# predictions : [[0.00669668 0.99330324]]
# 2nd bus branch
# predictions : [[0.12176402 0.878236  ]]
# 2nd bus branch
# predictions : [[0.01293509 0.98706496]]
# 2nd bus branch
# predictions : [[0.01153159 0.98846847]]
# 2nd bus branch
# predictions : [[0.03380956 0.9661904 ]]
# 2nd bus branch
# predictions : [[0.01178913 0.9882109 ]]
# 2nd bus branch
# predictions : [[0.00868304 0.9913169 ]]
# 2nd bus branch
# predictions : [[0.02581579 0.9741843 ]]
# 2nd bus branch
# predictions : [[0.00845173 0.99154824]]
# 2nd bus branch
# predictions : [[0.01051367 0.98948634]]
# 2nd bus branch
# predictions : [[0.01527063 0.98472935]]
# 2nd bus branch
# predictions : [[0.00376149 0.99623847]]
# 2nd bus branch
# predictions : [[0.34032243 0.65967757]]
# 2nd bus branch
# predictions : [[0.06242717 0.9375728 ]]
# 2nd bus branch
# predictions : [[0.00202466 0.9979754 ]]
# 2nd bus branch
# predictions : [[0.00298328 0.9970168 ]]
# 2nd bus branch
# predictions : [[0.0592664 0.9407336]]
# 2nd bus branch
# predictions : [[0.00448799 0.99551195]]
# 2nd bus branch
# predictions : [[0.02510933 0.9748907 ]]
# 2nd bus branch
# predictions : [[0.20607807 0.79392195]]
# 2nd bus branch
# predictions : [[0.00843496 0.991565  ]]
# 2nd bus branch
# predictions : [[0.01325101 0.986749  ]]
# 2nd bus branch
# predictions : [[6.900178e-04 9.993100e-01]]
# 2nd bus branch
# predictions : [[7.0030557e-04 9.9929965e-01]]
# 2nd bus branch
# predictions : [[0.00393494 0.9960651 ]]
# 2nd bus branch
# predictions : [[0.00482673 0.9951733 ]]
# 2nd bus branch
# predictions : [[0.01152975 0.9884702 ]]
# 2nd bus branch
# predictions : [[0.00119422 0.99880576]]
# 2nd bus branch
# predictions : [[0.00730069 0.9926993 ]]
# 2nd bus branch
# predictions : [[0.10958532 0.89041466]]
# 2nd bus branch
# predictions : [[0.18949439 0.81050557]]
# 2nd bus branch
# predictions : [[0.06612535 0.9338746 ]]
# 2nd bus branch
# predictions : [[0.2544028 0.7455972]]
# 2nd bus branch
# predictions : [[0.00854463 0.9914554 ]]
# 2nd bus branch
# predictions : [[0.01051914 0.98948085]]
# 2nd bus branch
# predictions : [[0.02436363 0.9756363 ]]
# 2nd bus branch
# predictions : [[0.01234249 0.98765755]]
# 2nd bus branch
# predictions : [[0.44841167 0.5515883 ]]
# 2nd bus branch
# predictions : [[0.01436094 0.98563904]]
# 2nd bus branch
# predictions : [[0.00927761 0.9907224 ]]
# 2nd bus branch
# predictions : [[0.0086744  0.99132556]]
# 2nd bus branch
# predictions : [[0.02116801 0.978832  ]]
# 2nd bus branch
# predictions : [[0.0185068 0.9814932]]
# 2nd bus branch
# predictions : [[0.03234896 0.967651  ]]
# 2nd bus branch
# predictions : [[0.02864663 0.9713534 ]]
# 2nd bus branch
# predictions : [[0.01793987 0.9820601 ]]
# 2nd bus branch
# predictions : [[0.01457168 0.9854283 ]]
# 1700
# 2nd bus branch
# predictions : [[0.05413776 0.94586223]]
# 2nd bus branch
# predictions : [[0.00957218 0.99042785]]
# 2nd bus branch
# predictions : [[0.02866352 0.97133654]]
# 2nd bus branch
# predictions : [[0.02087594 0.979124  ]]
# 2nd bus branch
# predictions : [[0.0018827 0.9981173]]
# 2nd bus branch
# predictions : [[0.00523629 0.99476373]]
# 2nd bus branch
# predictions : [[0.36141682 0.63858324]]
# 2nd bus branch
# predictions : [[0.01651696 0.9834831 ]]
# 2nd bus branch
# predictions : [[0.00215065 0.99784935]]
# 2nd bus branch
# predictions : [[0.02121795 0.9787821 ]]
# 2nd bus branch
# predictions : [[0.00803532 0.9919647 ]]
# 2nd bus branch
# predictions : [[0.05691146 0.9430885 ]]
# 2nd bus branch
# predictions : [[0.01583268 0.9841673 ]]
# 2nd bus branch
# predictions : [[0.01398311 0.9860169 ]]
# 2nd bus branch
# predictions : [[0.00438177 0.9956182 ]]
# 2nd bus branch
# predictions : [[0.00405941 0.99594057]]
# 2nd bus branch
# predictions : [[0.4143608 0.5856392]]
# 2nd bus branch
# predictions : [[0.09023178 0.9097682 ]]
# 2nd bus branch
# predictions : [[0.00439094 0.9956091 ]]
# 2nd bus branch
# predictions : [[0.01960331 0.9803966 ]]
# 2nd bus branch
# predictions : [[0.04263383 0.95736617]]
# 2nd bus branch
# predictions : [[0.23510332 0.7648967 ]]
# 2nd bus branch
# predictions : [[0.00317691 0.9968231 ]]
# 2nd bus branch
# predictions : [[0.00522005 0.99477994]]
# 2nd bus branch
# predictions : [[0.00365575 0.99634427]]
# 2nd bus branch
# predictions : [[0.00415943 0.9958405 ]]
# 2nd bus branch
# predictions : [[0.00667109 0.9933289 ]]
# 2nd bus branch
# predictions : [[0.04352551 0.9564744 ]]
# 2nd bus branch
# predictions : [[1.9870509e-04 9.9980134e-01]]
# 2nd bus branch
# predictions : [[0.00123188 0.99876803]]
# 2nd bus branch
# predictions : [[0.03229567 0.96770436]]
# 2nd bus branch
# predictions : [[5.7436945e-04 9.9942565e-01]]
# 2nd bus branch
# predictions : [[0.00322909 0.9967709 ]]
# 2nd bus branch
# predictions : [[0.00598778 0.9940122 ]]
# 1800
# 2nd bus branch
# predictions : [[0.00353557 0.9964644 ]]
# 2nd bus branch
# predictions : [[0.3579428 0.6420572]]
# 2nd bus branch
# predictions : [[0.01324129 0.98675877]]
# 2nd bus branch
# predictions : [[0.00323983 0.9967602 ]]
# 1900
# 2nd bus branch
# predictions : [[0.02130324 0.9786968 ]]
# 2000
# 2nd bus branch
# predictions : [[0.0286724  0.97132766]]
# 2nd bus branch
# predictions : [[0.00527721 0.99472284]]
# 2nd bus branch
# predictions : [[3.9176643e-04 9.9960822e-01]]
# 2nd bus branch
# predictions : [[0.00674622 0.99325377]]
# 2nd bus branch
# predictions : [[4.000539e-04 9.996000e-01]]
# 2nd bus branch
# predictions : [[5.487891e-04 9.994512e-01]]
# 2nd bus branch
# predictions : [[0.15703595 0.8429641 ]]
# 2nd bus branch
# predictions : [[0.16379142 0.8362086 ]]
# 2nd bus branch
# predictions : [[0.05380646 0.9461935 ]]
# 2nd bus branch
# predictions : [[0.0092163 0.9907837]]
# 2nd bus branch
# predictions : [[0.13060999 0.86939   ]]
# 2nd bus branch
# predictions : [[0.00328026 0.9967198 ]]
# 2nd bus branch
# predictions : [[0.00410379 0.9958962 ]]
# 2100
# 2nd bus branch
# predictions : [[0.00614738 0.9938526 ]]
# 2nd bus branch
# predictions : [[0.00432599 0.99567395]]
# 2nd bus branch
# predictions : [[0.00952787 0.9904722 ]]
# 2nd bus branch
# predictions : [[0.00109489 0.99890506]]
# 2nd bus branch
# predictions : [[0.00869417 0.99130577]]
# 2nd bus branch
# predictions : [[0.0013955 0.9986045]]
# 2nd bus branch
# predictions : [[0.00918406 0.9908159 ]]
# 2200
# 2nd bus branch
# predictions : [[4.9004651e-04 9.9950993e-01]]
# 2nd bus branch
# predictions : [[0.00517869 0.9948213 ]]
# 2nd bus branch
# predictions : [[0.00778738 0.9922126 ]]
# 2nd bus branch
# predictions : [[0.00243472 0.99756527]]
# 2nd bus branch
# predictions : [[5.2808016e-04 9.9947196e-01]]
# 2nd bus branch
# predictions : [[0.00261195 0.99738806]]
# 2nd bus branch
# predictions : [[0.00199885 0.99800116]]
# 2nd bus branch
# predictions : [[1.2208376e-04 9.9987793e-01]]
# 2nd bus branch
# predictions : [[0.00131867 0.99868137]]
# 2300
# 2nd bus branch
# predictions : [[0.20638609 0.7936139 ]]
# 2nd bus branch
# predictions : [[0.48862633 0.51137364]]
# 2nd bus branch
# predictions : [[0.01004508 0.98995495]]
# 2nd bus branch
# predictions : [[0.01009742 0.9899026 ]]
# 2nd bus branch
# predictions : [[0.01590276 0.98409724]]
# 2400
# 2nd bus branch
# predictions : [[0.00227868 0.99772125]]
# 2nd bus branch
# predictions : [[0.00266916 0.9973309 ]]
# 2nd bus branch
# predictions : [[0.28314802 0.71685195]]
# 2nd bus branch
# predictions : [[0.01267301 0.98732704]]
# 2nd bus branch
# predictions : [[1.2979793e-05 9.9998701e-01]]
# 2nd bus branch
# predictions : [[0.00503359 0.99496645]]
# 2nd bus branch
# predictions : [[1.6384014e-04 9.9983609e-01]]
# 2nd bus branch
# predictions : [[0.00764599 0.99235404]]
# 2nd bus branch
# predictions : [[0.03640746 0.9635925 ]]
# 2nd bus branch
# predictions : [[0.00820451 0.9917955 ]]
# 2nd bus branch
# predictions : [[0.01730398 0.98269606]]
# 2nd bus branch
# predictions : [[0.00283886 0.99716115]]
# 2nd bus branch
# predictions : [[0.00956403 0.9904359 ]]
# 2nd bus branch
# predictions : [[0.01878526 0.98121476]]
# 2nd bus branch
# predictions : [[0.03285112 0.96714884]]
# 2nd bus branch
# predictions : [[0.0083141 0.9916859]]
# 2nd bus branch
# predictions : [[0.00790517 0.9920948 ]]
# 2nd bus branch
# predictions : [[0.01311129 0.98688865]]
# 2nd bus branch
# predictions : [[0.00177876 0.9982212 ]]
# 2nd bus branch
# predictions : [[0.0085907  0.99140936]]
# 2nd bus branch
# predictions : [[4.3060342e-04 9.9956936e-01]]
# 2nd bus branch
# predictions : [[0.00158998 0.99841   ]]
# 2nd bus branch
# predictions : [[0.00284512 0.99715483]]
# 2nd bus branch
# predictions : [[0.25948137 0.74051857]]
# 2500
# 2nd bus branch
# predictions : [[0.0080347 0.9919653]]
# 2nd bus branch
# predictions : [[0.01666783 0.98333216]]
# 2nd bus branch
# predictions : [[0.00771074 0.99228925]]
# 2nd bus branch
# predictions : [[0.01090244 0.9890976 ]]
# 2nd bus branch
# predictions : [[0.07432327 0.9256767 ]]
# 2nd bus branch
# predictions : [[0.00858152 0.9914185 ]]
# 2nd bus branch
# predictions : [[0.01250981 0.98749024]]
# 2nd bus branch
# predictions : [[0.01328146 0.9867185 ]]
# 2nd bus branch
# predictions : [[0.02581583 0.97418416]]
# 2nd bus branch
# predictions : [[0.00985305 0.99014693]]
# 2nd bus branch
# predictions : [[0.16489597 0.835104  ]]
# 2nd bus branch
# predictions : [[0.02693045 0.97306955]]
# 2nd bus branch
# predictions : [[0.01776571 0.9822343 ]]
# 2nd bus branch
# predictions : [[0.00475355 0.99524647]]
# 2nd bus branch
# predictions : [[0.02792737 0.97207266]]
# 2nd bus branch
# predictions : [[0.02029724 0.9797028 ]]
# 2nd bus branch
# predictions : [[0.01152913 0.9884709 ]]
# 2nd bus branch
# predictions : [[0.00352248 0.99647754]]
# 2nd bus branch
# predictions : [[0.00762626 0.99237376]]
# 2nd bus branch
# predictions : [[0.01982072 0.9801793 ]]
# 2nd bus branch
# predictions : [[0.06319086 0.9368092 ]]
# 2nd bus branch
# predictions : [[0.02012424 0.9798758 ]]
# 2nd bus branch
# predictions : [[0.01347915 0.9865209 ]]
# 2nd bus branch
# predictions : [[0.0012617  0.99873835]]
# 2nd bus branch
# predictions : [[3.8012216e-04 9.9961984e-01]]
# 2nd bus branch
# predictions : [[0.00345998 0.99654007]]
# 2nd bus branch
# predictions : [[0.01845992 0.98154014]]
# 2nd bus branch
# predictions : [[0.03119407 0.96880597]]
# 2nd bus branch
# predictions : [[0.06360509 0.93639493]]
# 2nd bus branch
# predictions : [[0.01009405 0.989906  ]]
# 2nd bus branch
# predictions : [[0.00108398 0.99891603]]
# 2nd bus branch
# predictions : [[0.00845102 0.991549  ]]
# 2nd bus branch
# predictions : [[0.07854572 0.92145425]]
# 2nd bus branch
# predictions : [[0.0298199 0.9701801]]
# 2nd bus branch
# predictions : [[0.01041073 0.9895893 ]]
# 2nd bus branch
# predictions : [[0.01617693 0.9838231 ]]
# 2nd bus branch
# predictions : [[0.17182662 0.8281734 ]]
# 2nd bus branch
# predictions : [[0.4270294  0.57297057]]
# 2nd bus branch
# predictions : [[0.01611456 0.9838854 ]]
# 2nd bus branch
# predictions : [[0.00764489 0.9923551 ]]
# 2nd bus branch
# predictions : [[0.03179516 0.96820486]]
# 2nd bus branch
# predictions : [[0.011314   0.98868597]]
# 2nd bus branch
# predictions : [[0.01786017 0.9821399 ]]
# 2nd bus branch
# predictions : [[0.00455362 0.9954464 ]]
# 2nd bus branch
# predictions : [[5.976295e-04 9.994024e-01]]
# 2nd bus branch
# predictions : [[0.0070502  0.99294984]]
# 2nd bus branch
# predictions : [[0.01050565 0.9894944 ]]
# 2nd bus branch
# predictions : [[0.01231626 0.9876837 ]]
# 2nd bus branch
# predictions : [[0.09494431 0.90505564]]
# 2nd bus branch
# predictions : [[0.04725139 0.95274866]]
# 2nd bus branch
# predictions : [[0.09371722 0.9062828 ]]
# 2nd bus branch
# predictions : [[0.00899493 0.99100506]]
# 2nd bus branch
# predictions : [[0.09272852 0.90727144]]
# 2nd bus branch
# predictions : [[0.15113391 0.84886605]]
# 2nd bus branch
# predictions : [[0.01503547 0.98496455]]
# 2nd bus branch
# predictions : [[0.01360301 0.98639697]]
# 2nd bus branch
# predictions : [[0.00430031 0.99569976]]
# 2nd bus branch
# predictions : [[0.0023434 0.9976566]]
# 2nd bus branch
# predictions : [[0.00773928 0.99226075]]
# 2nd bus branch
# predictions : [[0.05249235 0.9475076 ]]
# 2nd bus branch
# predictions : [[0.00876843 0.9912315 ]]
# 2nd bus branch
# predictions : [[0.02579541 0.9742046 ]]
# 2nd bus branch
# predictions : [[0.00375564 0.99624443]]
# 2nd bus branch
# predictions : [[0.00342706 0.996573  ]]
# 2nd bus branch
# predictions : [[0.01374372 0.9862563 ]]
# 2600
# 2nd bus branch
# predictions : [[0.01850739 0.9814926 ]]
# 2nd bus branch
# predictions : [[0.00247453 0.9975255 ]]
# 2nd bus branch
# predictions : [[0.0072255 0.9927745]]
# 2nd bus branch
# predictions : [[0.01158 0.98842]]
# 2nd bus branch
# predictions : [[0.03572407 0.96427596]]
# 2nd bus branch
# predictions : [[0.00181863 0.99818134]]
# 2nd bus branch
# predictions : [[0.00964222 0.9903578 ]]
# 2nd bus branch
# predictions : [[0.01917672 0.9808233 ]]
# 2nd bus branch
# predictions : [[0.04905257 0.95094746]]
# 2nd bus branch
# predictions : [[0.00888908 0.9911109 ]]
# 2nd bus branch
# predictions : [[0.01263404 0.98736596]]
# 2nd bus branch
# predictions : [[0.00242233 0.9975777 ]]
# 2nd bus branch
# predictions : [[0.07558938 0.9244106 ]]
# 2nd bus branch
# predictions : [[0.01502331 0.98497665]]
# 2nd bus branch
# predictions : [[0.00882997 0.99117005]]
# 2nd bus branch
# predictions : [[0.00212242 0.9978776 ]]
# 2nd bus branch
# predictions : [[0.00540608 0.9945939 ]]
# 2nd bus branch
# predictions : [[0.04193566 0.9580643 ]]
# 2nd bus branch
# predictions : [[0.31598413 0.68401587]]
# 2nd bus branch
# predictions : [[0.00336695 0.9966331 ]]
# 2nd bus branch
# predictions : [[0.02859617 0.9714038 ]]
# 2nd bus branch
# predictions : [[0.00412109 0.99587893]]
# 2nd bus branch
# predictions : [[0.02459728 0.9754028 ]]
# 2nd bus branch
# predictions : [[0.03716535 0.9628346 ]]
# 2nd bus branch
# predictions : [[0.2237381  0.77626187]]
# 2nd bus branch
# predictions : [[0.06623317 0.9337668 ]]
# 2nd bus branch
# predictions : [[0.022087   0.97791296]]
# 2nd bus branch
# predictions : [[0.04164932 0.95835066]]
# 2nd bus branch
# predictions : [[0.00899545 0.9910046 ]]
# 2nd bus branch
# predictions : [[0.04849149 0.95150846]]
# 2nd bus branch
# predictions : [[0.01895689 0.9810431 ]]
# 2nd bus branch
# predictions : [[0.01522734 0.9847727 ]]
# 2nd bus branch
# predictions : [[0.04437723 0.9556228 ]]
# 2nd bus branch
# predictions : [[0.02657353 0.9734265 ]]
# 2nd bus branch
# predictions : [[0.09996573 0.90003425]]
# 2nd bus branch
# predictions : [[0.0262436  0.97375643]]
# 2nd bus branch
# predictions : [[0.10426568 0.8957343 ]]
# 2nd bus branch
# predictions : [[0.0989624  0.90103763]]
# 2nd bus branch
# predictions : [[0.00619738 0.99380255]]
# 2nd bus branch
# predictions : [[0.01676951 0.9832305 ]]
# 2nd bus branch
# predictions : [[0.05074731 0.9492527 ]]
# 2nd bus branch
# predictions : [[0.05557313 0.94442683]]
# 2nd bus branch
# predictions : [[0.00691803 0.993082  ]]
# 2nd bus branch
# predictions : [[1.7714078e-04 9.9982291e-01]]
# 2nd bus branch
# predictions : [[5.4809306e-04 9.9945194e-01]]
# 2nd bus branch
# predictions : [[0.00178528 0.9982147 ]]
# 2nd bus branch
# predictions : [[7.7972491e-04 9.9922025e-01]]
# 2nd bus branch
# predictions : [[0.00259652 0.99740344]]
# 2700
# 2nd bus branch
# predictions : [[2.1469788e-04 9.9978536e-01]]
# 2nd bus branch
# predictions : [[0.00307902 0.99692106]]
# 2nd bus branch
# predictions : [[8.4129930e-04 9.9915874e-01]]
# 2nd bus branch
# predictions : [[7.8844285e-04 9.9921155e-01]]
# 2nd bus branch
# predictions : [[0.00598863 0.99401134]]
# 2nd bus branch
# predictions : [[0.01036737 0.9896326 ]]
# 2nd bus branch
# predictions : [[0.00884928 0.99115074]]
# 2nd bus branch
# predictions : [[7.3208386e-04 9.9926788e-01]]
# 2nd bus branch
# predictions : [[0.0019986 0.9980014]]
# 2nd bus branch
# predictions : [[0.00197885 0.9980211 ]]
# 2nd bus branch
# predictions : [[0.00421048 0.9957896 ]]
# 2nd bus branch
# predictions : [[0.00152748 0.9984725 ]]
# 2nd bus branch
# predictions : [[4.0466237e-04 9.9959534e-01]]
# 2nd bus branch
# predictions : [[0.00127986 0.99872017]]
# 2nd bus branch
# predictions : [[7.127699e-04 9.992873e-01]]
# 2800
# 2nd bus branch
# predictions : [[5.9662841e-04 9.9940336e-01]]
# 2nd bus branch
# predictions : [[7.9002185e-04 9.9921000e-01]]
# 2nd bus branch
# predictions : [[6.5873726e-04 9.9934119e-01]]
# 2nd bus branch
# predictions : [[3.2425279e-04 9.9967575e-01]]
# 2nd bus branch
# predictions : [[0.00717018 0.99282986]]
# 2nd bus branch
# predictions : [[0.03435836 0.9656416 ]]
# 2nd bus branch
# predictions : [[3.7555132e-04 9.9962437e-01]]
# 2nd bus branch
# predictions : [[0.00834534 0.99165463]]
# 2nd bus branch
# predictions : [[0.00392117 0.9960788 ]]
# 2nd bus branch
# predictions : [[0.00176211 0.99823785]]
# 2nd bus branch
# predictions : [[0.00481175 0.99518824]]
# 2nd bus branch
# predictions : [[0.02111847 0.9788816 ]]
# 2nd bus branch
# predictions : [[0.00278243 0.99721754]]
# 2nd bus branch
# predictions : [[5.1931129e-04 9.9948066e-01]]
# 2900
# 2nd bus branch
# predictions : [[0.00391481 0.99608517]]
# 2nd bus branch
# predictions : [[0.03285503 0.9671449 ]]
# 2nd bus branch
# predictions : [[0.00540207 0.9945979 ]]
# 2nd bus branch
# predictions : [[0.03030019 0.9696998 ]]
# 2nd bus branch
# predictions : [[6.0094858e-04 9.9939907e-01]]
# 2nd bus branch
# predictions : [[0.0025399 0.9974602]]
# 2nd bus branch
# predictions : [[0.03171621 0.9682837 ]]
# 3000
# 2nd bus branch
# predictions : [[2.9871133e-04 9.9970120e-01]]
# 2nd bus branch
# predictions : [[1.1559129e-04 9.9988437e-01]]
# 2nd bus branch
# predictions : [[1.1076781e-04 9.9988925e-01]]
# 2nd bus branch
# predictions : [[0.16656613 0.8334338 ]]
# 2nd bus branch
# predictions : [[0.0272392  0.97276086]]
# 2nd bus branch
# predictions : [[0.01400478 0.98599523]]
# 2nd bus branch
# predictions : [[0.2851419 0.7148582]]
# 2nd bus branch
# predictions : [[0.04421525 0.95578474]]
# 2nd bus branch
# predictions : [[3.8478183e-04 9.9961519e-01]]
# 2nd bus branch
# predictions : [[0.01789975 0.9821002 ]]
# 2nd bus branch
# predictions : [[0.00119278 0.9988072 ]]
# 2nd bus branch
# predictions : [[0.03203927 0.9679607 ]]
# 2nd bus branch
# predictions : [[0.00368657 0.9963134 ]]
# 2nd bus branch
# predictions : [[0.004208   0.99579203]]
# 2nd bus branch
# predictions : [[0.00168259 0.9983175 ]]
# 2nd bus branch
# predictions : [[0.00146414 0.9985359 ]]
# 2nd bus branch
# predictions : [[3.874503e-04 9.996126e-01]]
# 2nd bus branch
# predictions : [[0.0038087  0.99619126]]
# 2nd bus branch
# predictions : [[0.00106429 0.99893576]]
# 2nd bus branch
# predictions : [[0.00531123 0.99468875]]
# 2nd bus branch
# predictions : [[0.00385388 0.9961461 ]]
# 2nd bus branch
# predictions : [[0.00150728 0.9984927 ]]
# 2nd bus branch
# predictions : [[0.01443549 0.98556453]]
# 2nd bus branch
# predictions : [[3.8380697e-04 9.9961615e-01]]
# 2nd bus branch
# predictions : [[0.00325953 0.9967405 ]]
# 3100
# 2nd bus branch
# predictions : [[6.1967649e-04 9.9938035e-01]]
# 2nd bus branch
# predictions : [[0.02738927 0.9726107 ]]
# 2nd bus branch
# predictions : [[0.01337359 0.98662645]]
# 2nd bus branch
# predictions : [[5.577139e-04 9.994423e-01]]
# 2nd bus branch
# predictions : [[5.658207e-04 9.994342e-01]]
# 2nd bus branch
# predictions : [[0.00180165 0.99819833]]
# 2nd bus branch
# predictions : [[0.00349099 0.996509  ]]
# 2nd bus branch
# predictions : [[0.00669437 0.9933056 ]]
# 2nd bus branch
# predictions : [[4.8534732e-04 9.9951470e-01]]
# 2nd bus branch
# predictions : [[0.00104225 0.99895775]]
# 2nd bus branch
# predictions : [[0.00631944 0.9936806 ]]
# 2nd bus branch
# predictions : [[8.550788e-05 9.999145e-01]]
# 2nd bus branch
# predictions : [[0.00168904 0.9983109 ]]
# 2nd bus branch
# predictions : [[9.013244e-05 9.999099e-01]]
# 2nd bus branch
# predictions : [[4.197263e-04 9.995803e-01]]
# 2nd bus branch
# predictions : [[0.00364118 0.9963588 ]]
# 2nd bus branch
# predictions : [[0.00101963 0.99898034]]
# 2nd bus branch
# predictions : [[0.00399679 0.9960032 ]]
# 2nd bus branch
# predictions : [[0.03182844 0.96817154]]
# 2nd bus branch
# predictions : [[0.00101873 0.9989813 ]]
# 2nd bus branch
# predictions : [[5.036072e-05 9.999497e-01]]
# 2nd bus branch
# predictions : [[0.00325025 0.99674976]]
# 2nd bus branch
# predictions : [[0.36751315 0.6324869 ]]
# 2nd bus branch
# predictions : [[9.4904023e-04 9.9905092e-01]]
# 2nd bus branch
# predictions : [[0.00168272 0.99831736]]
# 2nd bus branch
# predictions : [[0.00238395 0.99761605]]
# 2nd bus branch
# predictions : [[0.0018312 0.9981688]]
# 2nd bus branch
# predictions : [[0.01745833 0.9825417 ]]
# 2nd bus branch
# predictions : [[0.00282556 0.9971744 ]]
# 2nd bus branch
# predictions : [[0.01102089 0.9889791 ]]
# 2nd bus branch
# predictions : [[0.00562837 0.99437165]]
# 2nd bus branch
# predictions : [[0.02267003 0.97732997]]
# 2nd bus branch
# predictions : [[9.3827612e-04 9.9906176e-01]]
# 2nd bus branch
# predictions : [[0.02750052 0.97249943]]
# 2nd bus branch
# predictions : [[4.5927553e-04 9.9954081e-01]]
# 2nd bus branch
# predictions : [[0.01958782 0.98041224]]
# 2nd bus branch
# predictions : [[0.01448579 0.98551416]]
# 2nd bus branch
# predictions : [[2.3289968e-04 9.9976712e-01]]
# 2nd bus branch
# predictions : [[0.0013417 0.9986583]]
# 2nd bus branch
# predictions : [[0.04444684 0.9555531 ]]
# 2nd bus branch
# predictions : [[3.7397080e-04 9.9962604e-01]]
# 2nd bus branch
# predictions : [[0.00857641 0.99142355]]
# 2nd bus branch
# predictions : [[1.9845348e-04 9.9980158e-01]]
# 3200
# 2nd bus branch
# predictions : [[1.9845007e-04 9.9980158e-01]]
# 2nd bus branch
# predictions : [[3.8493722e-04 9.9961507e-01]]
# 2nd bus branch
# predictions : [[0.00123999 0.99876   ]]
# 2nd bus branch
# predictions : [[0.00131527 0.9986847 ]]
# 2nd bus branch
# predictions : [[0.00477976 0.99522024]]
# 2nd bus branch
# predictions : [[0.01148533 0.9885147 ]]
# 2nd bus branch
# predictions : [[8.4052922e-04 9.9915946e-01]]
# 2nd bus branch
# predictions : [[7.3664641e-04 9.9926335e-01]]
# 2nd bus branch
# predictions : [[6.362815e-04 9.993637e-01]]
# 2nd bus branch
# predictions : [[0.00102964 0.9989704 ]]
# 2nd bus branch
# predictions : [[0.00102134 0.99897873]]
# 2nd bus branch
# predictions : [[0.00283114 0.99716884]]
# 2nd bus branch
# predictions : [[0.01128428 0.9887157 ]]
# 2nd bus branch
# predictions : [[0.00254099 0.997459  ]]
# 2nd bus branch
# predictions : [[0.00106119 0.99893886]]
# 2nd bus branch
# predictions : [[0.00393005 0.9960699 ]]
# 2nd bus branch
# predictions : [[0.0018391 0.9981609]]
# 2nd bus branch
# predictions : [[4.803242e-04 9.995197e-01]]
# 2nd bus branch
# predictions : [[0.00141557 0.9985844 ]]
# 2nd bus branch
# predictions : [[0.00911566 0.99088436]]
# 2nd bus branch
# predictions : [[0.00212198 0.9978781 ]]
# 2nd bus branch
# predictions : [[4.7306926e-04 9.9952698e-01]]
# 2nd bus branch
# predictions : [[0.01566063 0.98433936]]
# 2nd bus branch
# predictions : [[2.127530e-04 9.997873e-01]]
# 2nd bus branch
# predictions : [[0.01041594 0.989584  ]]
# 2nd bus branch
# predictions : [[0.00536443 0.9946355 ]]
# 2nd bus branch
# predictions : [[0.00994298 0.99005705]]
# 2nd bus branch
# predictions : [[6.9791065e-05 9.9993026e-01]]
# 2nd bus branch
# predictions : [[3.2130774e-06 9.9999678e-01]]
# 2nd bus branch
# predictions : [[7.958619e-04 9.992042e-01]]
# 2nd bus branch
# predictions : [[0.20508069 0.7949193 ]]
# 2nd bus branch
# predictions : [[0.01094427 0.98905575]]
# 2nd bus branch
# predictions : [[0.01362746 0.98637253]]
# 2nd bus branch
# predictions : [[0.02254049 0.9774595 ]]
# 2nd bus branch
# predictions : [[0.00139266 0.99860734]]
# 2nd bus branch
# predictions : [[0.00181089 0.99818915]]
# 2nd bus branch
# predictions : [[7.374598e-04 9.992625e-01]]
# 2nd bus branch
# predictions : [[0.00227056 0.9977295 ]]
# 2nd bus branch
# predictions : [[2.7261584e-04 9.9972743e-01]]
# 2nd bus branch
# predictions : [[0.00188867 0.99811137]]
# 2nd bus branch
# predictions : [[0.00149284 0.9985071 ]]
# 2nd bus branch
# predictions : [[0.00119082 0.9988092 ]]
# 2nd bus branch
# predictions : [[0.00172195 0.998278  ]]
# 2nd bus branch
# predictions : [[0.00257303 0.9974269 ]]
# 3300
# 2nd bus branch
# predictions : [[0.00569895 0.9943011 ]]
# 2nd bus branch
# predictions : [[5.2189123e-04 9.9947816e-01]]
# 2nd bus branch
# predictions : [[0.00128207 0.9987179 ]]
# 2nd bus branch
# predictions : [[0.00680531 0.9931947 ]]
# 2nd bus branch
# predictions : [[0.00495349 0.9950465 ]]
# 2nd bus branch
# predictions : [[0.00320048 0.99679947]]
# 2nd bus branch
# predictions : [[6.0452183e-04 9.9939549e-01]]
# 2nd bus branch
# predictions : [[0.00481792 0.9951821 ]]
# 2nd bus branch
# predictions : [[2.7988842e-04 9.9972004e-01]]
# 2nd bus branch
# predictions : [[8.2328403e-04 9.9917668e-01]]
# 2nd bus branch
# predictions : [[0.00143606 0.99856395]]
# 2nd bus branch
# predictions : [[0.00108455 0.99891543]]
# 2nd bus branch
# predictions : [[0.02834368 0.97165626]]
# 2nd bus branch
# predictions : [[0.02980828 0.97019166]]
# 2nd bus branch
# predictions : [[0.0100631 0.9899368]]
# 2nd bus branch
# predictions : [[0.11960874 0.88039124]]
# 2nd bus branch
# predictions : [[0.153029 0.846971]]
# 2nd bus branch
# predictions : [[0.00225499 0.99774504]]
# 2nd bus branch
# predictions : [[0.00175263 0.9982474 ]]
# 2nd bus branch
# predictions : [[0.00265924 0.99734074]]
# 3400
# 2nd bus branch
# predictions : [[0.00391005 0.99608994]]
# 2nd bus branch
# predictions : [[0.00118602 0.998814  ]]
# 2nd bus branch
# predictions : [[0.00122885 0.99877113]]
# 2nd bus branch
# predictions : [[0.01252574 0.9874743 ]]
# 2nd bus branch
# predictions : [[0.00560536 0.99439466]]
# 2nd bus branch
# predictions : [[0.00108438 0.9989157 ]]
# 2nd bus branch
# predictions : [[4.7112815e-04 9.9952888e-01]]
# 2nd bus branch
# predictions : [[1.7853394e-04 9.9982148e-01]]
# 2nd bus branch
# predictions : [[0.00363534 0.99636465]]
# 2nd bus branch
# predictions : [[0.00301103 0.99698895]]
# 2nd bus branch
# predictions : [[0.00396528 0.9960347 ]]
# 2nd bus branch
# predictions : [[0.00312797 0.996872  ]]
# 2nd bus branch
# predictions : [[0.28592724 0.7140727 ]]
# 2nd bus branch
# predictions : [[0.00410227 0.9958977 ]]
# 2nd bus branch
# predictions : [[0.00366918 0.9963308 ]]
# 2nd bus branch
# predictions : [[0.01518405 0.98481596]]
# 2nd bus branch
# predictions : [[7.312991e-04 9.992687e-01]]
# 2nd bus branch
# predictions : [[0.01081441 0.9891856 ]]
# 2nd bus branch
# predictions : [[0.01507687 0.9849231 ]]
# 2nd bus branch
# predictions : [[0.00164189 0.9983581 ]]
# 2nd bus branch
# predictions : [[0.00203191 0.997968  ]]
# 2nd bus branch
# predictions : [[0.00103725 0.99896276]]
# 2nd bus branch
# predictions : [[0.00733041 0.9926696 ]]
# 2nd bus branch
# predictions : [[0.07613957 0.9238604 ]]
# 2nd bus branch
# predictions : [[0.00518297 0.9948171 ]]
# 2nd bus branch
# predictions : [[0.0104543  0.98954564]]
# 2nd bus branch
# predictions : [[0.0274152 0.9725848]]
# 2nd bus branch
# predictions : [[0.00188738 0.9981127 ]]
# 2nd bus branch
# predictions : [[0.00544779 0.9945522 ]]
# 2nd bus branch
# predictions : [[0.00925379 0.99074614]]
# 2nd bus branch
# predictions : [[9.7268115e-04 9.9902737e-01]]
# 2nd bus branch
# predictions : [[0.00105613 0.99894387]]
# 2nd bus branch
# predictions : [[4.1152115e-04 9.9958843e-01]]
# 2nd bus branch
# predictions : [[5.2588724e-04 9.9947411e-01]]
# 2nd bus branch
# predictions : [[0.00145123 0.9985487 ]]
# 2nd bus branch
# predictions : [[0.00367882 0.9963212 ]]
# 2nd bus branch
# predictions : [[0.00152677 0.9984732 ]]
# 2nd bus branch
# predictions : [[8.1106101e-04 9.9918896e-01]]
# 2nd bus branch
# predictions : [[0.00120468 0.9987953 ]]
# 2nd bus branch
# predictions : [[2.1715793e-04 9.9978286e-01]]
# 3500
# 2nd bus branch
# predictions : [[0.00166892 0.9983311 ]]
# 2nd bus branch
# predictions : [[0.0011132  0.99888676]]
# 2nd bus branch
# predictions : [[0.01288144 0.9871186 ]]
# 2nd bus branch
# predictions : [[6.352157e-04 9.993648e-01]]
# 2nd bus branch
# predictions : [[3.1603017e-04 9.9968398e-01]]
# 2nd bus branch
# predictions : [[0.01242811 0.98757184]]
# 2nd bus branch
# predictions : [[0.0680465  0.93195355]]
# 2nd bus branch
# predictions : [[0.02907594 0.970924  ]]
# 2nd bus branch
# predictions : [[0.06686324 0.9331367 ]]
# 2nd bus branch
# predictions : [[0.05843429 0.94156563]]
# 2nd bus branch
# predictions : [[0.02048129 0.9795187 ]]
# 2nd bus branch
# predictions : [[0.07055836 0.9294417 ]]
# 2nd bus branch
# predictions : [[0.00618056 0.9938194 ]]
# 2nd bus branch
# predictions : [[0.06696614 0.9330339 ]]
# 2nd bus branch
# predictions : [[0.26212943 0.7378706 ]]
# 2nd bus branch
# predictions : [[0.01416367 0.98583627]]
# 2nd bus branch
# predictions : [[0.08426867 0.9157313 ]]
# 2nd bus branch
# predictions : [[0.04852356 0.9514764 ]]
# 2nd bus branch
# predictions : [[0.00105695 0.99894303]]
# 2nd bus branch
# predictions : [[0.00161365 0.9983864 ]]
# 2nd bus branch
# predictions : [[0.00906141 0.99093854]]
# 2nd bus branch
# predictions : [[0.01393769 0.98606235]]
# 2nd bus branch
# predictions : [[0.00592034 0.9940797 ]]
# 2nd bus branch
# predictions : [[0.001462 0.998538]]
# 2nd bus branch
# predictions : [[0.00226356 0.99773645]]
# 3600
# 2nd bus branch
# predictions : [[0.01906506 0.9809349 ]]
# 2nd bus branch
# predictions : [[0.14348423 0.8565157 ]]
# 2nd bus branch
# predictions : [[0.4275816 0.5724184]]
# 2nd bus branch
# predictions : [[0.00668425 0.99331576]]
# 2nd bus branch
# predictions : [[1.2960873e-04 9.9987042e-01]]
# 2nd bus branch
# predictions : [[0.04346091 0.9565391 ]]
# 2nd bus branch
# predictions : [[4.4917196e-04 9.9955076e-01]]
# 2nd bus branch
# predictions : [[0.00472786 0.9952721 ]]
# 2nd bus branch
# predictions : [[2.0861278e-04 9.9979144e-01]]
# 2nd bus branch
# predictions : [[0.0070245 0.9929755]]
# 2nd bus branch
# predictions : [[0.00737463 0.9926254 ]]
# 2nd bus branch
# predictions : [[0.0690048  0.93099517]]
# 2nd bus branch
# predictions : [[0.00149045 0.9985096 ]]
# 2nd bus branch
# predictions : [[0.00546171 0.99453825]]
# 3700
# 2nd bus branch
# predictions : [[0.02097666 0.97902334]]
# 2nd bus branch
# predictions : [[0.01640016 0.9835999 ]]
# 2nd bus branch
# predictions : [[0.00395227 0.9960477 ]]
# 2nd bus branch
# predictions : [[0.00218872 0.99781126]]
# 2nd bus branch
# predictions : [[1.08261185e-04 9.99891758e-01]]
# 2nd bus branch
# predictions : [[4.2312942e-04 9.9957687e-01]]
# 2nd bus branch
# predictions : [[0.00525378 0.9947462 ]]
# 2nd bus branch
# predictions : [[0.01256927 0.9874307 ]]
# 2nd bus branch
# predictions : [[0.02613192 0.973868  ]]
# 2nd bus branch
# predictions : [[0.01590911 0.98409086]]
# 2nd bus branch
# predictions : [[0.00324335 0.9967566 ]]
# 2nd bus branch
# predictions : [[0.02736305 0.972637  ]]
# 2nd bus branch
# predictions : [[0.00667854 0.9933215 ]]
# 2nd bus branch
# predictions : [[0.01853306 0.98146695]]
# 2nd bus branch
# predictions : [[0.00540846 0.99459153]]
# 2nd bus branch
# predictions : [[0.00272362 0.99727637]]
# 2nd bus branch
# predictions : [[0.00746486 0.9925351 ]]
# 3800
# 2nd bus branch
# predictions : [[0.00380716 0.9961928 ]]
# 2nd bus branch
# predictions : [[0.00160346 0.9983966 ]]
# 2nd bus branch
# predictions : [[1.2517985e-04 9.9987483e-01]]
# 2nd bus branch
# predictions : [[0.00981924 0.99018073]]
# 2nd bus branch
# predictions : [[0.0706679  0.92933214]]
# 2nd bus branch
# predictions : [[0.20815921 0.7918408 ]]
# 2nd bus branch
# predictions : [[0.07495138 0.9250486 ]]
# 3900
# 2nd bus branch
# predictions : [[1.8306400e-04 9.9981695e-01]]
# 2nd bus branch
# predictions : [[0.00229952 0.9977005 ]]
# 2nd bus branch
# predictions : [[7.8532416e-05 9.9992144e-01]]
# 2nd bus branch
# predictions : [[0.0056393  0.99436074]]
# 2nd bus branch
# predictions : [[0.07072832 0.9292717 ]]
# 2nd bus branch
# predictions : [[0.00507154 0.9949285 ]]
# 2nd bus branch
# predictions : [[0.01002842 0.9899715 ]]
# 2nd bus branch
# predictions : [[0.39904338 0.6009566 ]]
# 2nd bus branch
# predictions : [[0.00477573 0.99522424]]
# 4000
# 2nd bus branch
# predictions : [[0.08576164 0.9142384 ]]
# 2nd bus branch
# predictions : [[0.25533321 0.74466676]]
# 2nd bus branch
# predictions : [[0.01906739 0.9809326 ]]
# 2nd bus branch
# predictions : [[0.02812645 0.9718736 ]]
# 2nd bus branch
# predictions : [[0.38004398 0.6199561 ]]
# 2nd bus branch
# predictions : [[0.00918216 0.9908179 ]]
# 2nd bus branch
# predictions : [[0.02034186 0.9796581 ]]
# 2nd bus branch
# predictions : [[0.02335982 0.9766402 ]]
# 2nd bus branch
# predictions : [[0.00610938 0.99389064]]
# 2nd bus branch
# predictions : [[0.01796867 0.98203135]]
# 2nd bus branch
# predictions : [[0.00416176 0.9958383 ]]
# 2nd bus branch
# predictions : [[0.00360835 0.9963916 ]]
# 4100
# 2nd bus branch
# predictions : [[0.01585433 0.9841457 ]]
# 2nd bus branch
# predictions : [[0.00510053 0.99489945]]
# 2nd bus branch
# predictions : [[0.09806216 0.90193784]]
# 2nd bus branch
# predictions : [[0.00611998 0.99388003]]
# 2nd bus branch
# predictions : [[0.00122871 0.99877125]]
# 2nd bus branch
# predictions : [[0.00967574 0.99032426]]
# 2nd bus branch
# predictions : [[0.0024338 0.9975662]]
# 2nd bus branch
# predictions : [[0.00152012 0.9984799 ]]
# 2nd bus branch
# predictions : [[0.00114279 0.99885726]]
# 2nd bus branch
# predictions : [[0.0070795  0.99292046]]
# 2nd bus branch
# predictions : [[0.00429147 0.99570847]]
# 4200
# 2nd bus branch
# predictions : [[0.00326694 0.99673307]]
# 2nd bus branch
# predictions : [[0.00347662 0.9965233 ]]
# 2nd bus branch
# predictions : [[0.00206313 0.99793684]]
# 2nd bus branch
# predictions : [[0.01394497 0.9860551 ]]
# 2nd bus branch
# predictions : [[0.0039088 0.9960912]]
# 2nd bus branch
# predictions : [[5.7432475e-04 9.9942565e-01]]
# 2nd bus branch
# predictions : [[0.00967062 0.9903294 ]]
# 2nd bus branch
# predictions : [[0.01601426 0.9839857 ]]
# 2nd bus branch
# predictions : [[0.00494233 0.9950577 ]]
# 2nd bus branch
# predictions : [[0.49843636 0.5015636 ]]
# 2nd bus branch
# predictions : [[0.00942446 0.99057555]]
# 2nd bus branch
# predictions : [[0.01394682 0.9860532 ]]
# 2nd bus branch
# predictions : [[6.8415992e-04 9.9931586e-01]]
# 2nd bus branch
# predictions : [[2.4427703e-04 9.9975568e-01]]
# 2nd bus branch
# predictions : [[0.00856895 0.99143106]]
# 2nd bus branch
# predictions : [[6.002686e-04 9.993998e-01]]
# 2nd bus branch
# predictions : [[3.175717e-04 9.996824e-01]]
# 2nd bus branch
# predictions : [[9.5821643e-04 9.9904174e-01]]
# 2nd bus branch
# predictions : [[0.00121612 0.9987839 ]]
# 2nd bus branch
# predictions : [[0.00350392 0.99649614]]
# 2nd bus branch
# predictions : [[0.00123223 0.99876785]]
# 4300
# 2nd bus branch
# predictions : [[0.00412457 0.9958754 ]]
# 2nd bus branch
# predictions : [[0.00247799 0.99752194]]
# 2nd bus branch
# predictions : [[0.00143212 0.9985678 ]]
# 2nd bus branch
# predictions : [[0.00291781 0.9970822 ]]
# 2nd bus branch
# predictions : [[0.00490949 0.9950905 ]]
# 2nd bus branch
# predictions : [[0.00631702 0.993683  ]]
# 2nd bus branch
# predictions : [[0.0234241  0.97657585]]
# 2nd bus branch
# predictions : [[0.00688306 0.993117  ]]
# 2nd bus branch
# predictions : [[0.00289059 0.9971095 ]]
# 2nd bus branch
# predictions : [[0.27765772 0.7223423 ]]
# 2nd bus branch
# predictions : [[0.01132942 0.9886706 ]]
# 2nd bus branch
# predictions : [[0.03785111 0.9621489 ]]
# 2nd bus branch
# predictions : [[0.0302912  0.96970874]]
# 2nd bus branch
# predictions : [[7.706500e-04 9.992293e-01]]
# 4400
# 2nd bus branch
# predictions : [[0.13286825 0.8671317 ]]
# 2nd bus branch
# predictions : [[0.00653227 0.99346775]]
# 2nd bus branch
# predictions : [[0.00616364 0.99383634]]
# 2nd bus branch
# predictions : [[0.00648666 0.9935134 ]]
# 2nd bus branch
# predictions : [[0.01587498 0.984125  ]]
# 2nd bus branch
# predictions : [[0.00287108 0.9971289 ]]
# 2nd bus branch
# predictions : [[0.00146222 0.9985378 ]]
# 2nd bus branch
# predictions : [[0.01848347 0.9815166 ]]
# 2nd bus branch
# predictions : [[0.00581422 0.9941858 ]]
# 2nd bus branch
# predictions : [[0.01676893 0.98323107]]
# 2nd bus branch
# predictions : [[0.00335047 0.99664956]]
# 2nd bus branch
# predictions : [[0.00726516 0.9927348 ]]
# 2nd bus branch
# predictions : [[0.00306938 0.99693066]]
# 2nd bus branch
# predictions : [[0.00293919 0.99706084]]
# 2nd bus branch
# predictions : [[0.00331416 0.9966858 ]]
# 2nd bus branch
# predictions : [[0.00279846 0.99720156]]
# 2nd bus branch
# predictions : [[9.6222077e-04 9.9903786e-01]]
# 2nd bus branch
# predictions : [[0.0026896 0.9973104]]
# 4500
# 2nd bus branch
# predictions : [[0.00103786 0.99896216]]
# 2nd bus branch
# predictions : [[0.00118702 0.99881303]]
# 2nd bus branch
# predictions : [[0.00199151 0.99800855]]
# 2nd bus branch
# predictions : [[0.00334562 0.9966544 ]]
# 2nd bus branch
# predictions : [[0.01231169 0.98768836]]
# 2nd bus branch
# predictions : [[4.3325260e-04 9.9956673e-01]]
# 2nd bus branch
# predictions : [[0.00552808 0.9944719 ]]
# 2nd bus branch
# predictions : [[0.02363228 0.9763678 ]]
# 2nd bus branch
# predictions : [[0.00708361 0.99291635]]
# 2nd bus branch
# predictions : [[8.190391e-04 9.991810e-01]]
# 2nd bus branch
# predictions : [[0.00547538 0.9945246 ]]
# 2nd bus branch
# predictions : [[0.11481733 0.8851827 ]]
# 2nd bus branch
# predictions : [[0.0019238 0.9980762]]
# 2nd bus branch
# predictions : [[0.00602545 0.9939745 ]]
# 2nd bus branch
# predictions : [[0.00291792 0.99708205]]
# 2nd bus branch
# predictions : [[0.00908213 0.99091786]]
# 2nd bus branch
# predictions : [[0.00315512 0.9968449 ]]
# 2nd bus branch
# predictions : [[0.00419661 0.9958034 ]]
# 2nd bus branch
# predictions : [[0.00650047 0.9934995 ]]
# 2nd bus branch
# predictions : [[0.00295558 0.9970444 ]]
# 2nd bus branch
# predictions : [[0.00281803 0.997182  ]]
# 2nd bus branch
# predictions : [[0.00407276 0.9959273 ]]
# 2nd bus branch
# predictions : [[0.00385928 0.9961408 ]]
# 2nd bus branch
# predictions : [[9.5707417e-04 9.9904293e-01]]
# 2nd bus branch
# predictions : [[4.9918750e-04 9.9950075e-01]]
# 2nd bus branch
# predictions : [[0.00156958 0.99843043]]
# 2nd bus branch
# predictions : [[0.00254802 0.99745196]]
# 2nd bus branch
# predictions : [[0.00189913 0.99810094]]
# 4600
# 2nd bus branch
# predictions : [[0.02329834 0.9767016 ]]
# 2nd bus branch
# predictions : [[0.01155666 0.9884433 ]]
# 2nd bus branch
# predictions : [[0.00204965 0.9979504 ]]
# 2nd bus branch
# predictions : [[0.0030989  0.99690115]]
# 2nd bus branch
# predictions : [[9.645909e-04 9.990355e-01]]
# 2nd bus branch
# predictions : [[9.561532e-04 9.990439e-01]]
# 2nd bus branch
# predictions : [[0.0019466  0.99805343]]
# 2nd bus branch
# predictions : [[0.00678324 0.9932167 ]]
# 2nd bus branch
# predictions : [[0.00668365 0.99331635]]
# 2nd bus branch
# predictions : [[4.7201998e-04 9.9952805e-01]]
# 2nd bus branch
# predictions : [[6.9165783e-04 9.9930835e-01]]
# 2nd bus branch
# predictions : [[0.0014974 0.9985026]]
# 2nd bus branch
# predictions : [[0.00114696 0.9988531 ]]
# 2nd bus branch
# predictions : [[0.00307237 0.9969277 ]]
# 2nd bus branch
# predictions : [[8.4990292e-04 9.9915004e-01]]
# 2nd bus branch
# predictions : [[0.00352526 0.9964747 ]]
# 2nd bus branch
# predictions : [[2.528134e-04 9.997472e-01]]
# 4700
# 2nd bus branch
# predictions : [[0.00183764 0.9981623 ]]
# 2nd bus branch
# predictions : [[0.00203044 0.99796957]]
# 2nd bus branch
# predictions : [[0.00532042 0.9946795 ]]
# 2nd bus branch
# predictions : [[5.3373910e-04 9.9946624e-01]]
# 2nd bus branch
# predictions : [[0.00357381 0.99642617]]
# 2nd bus branch
# predictions : [[1.5793620e-04 9.9984205e-01]]
# 2nd bus branch
# predictions : [[0.15572573 0.8442743 ]]
# 2nd bus branch
# predictions : [[0.47479886 0.52520114]]
# 2nd bus branch
# predictions : [[0.48284444 0.5171555 ]]
# 2nd bus branch
# predictions : [[1.9424685e-04 9.9980575e-01]]
# 2nd bus branch
# predictions : [[0.0016211 0.9983789]]
# 4800
# 2nd bus branch
# predictions : [[0.00114123 0.9988588 ]]
# 2nd bus branch
# predictions : [[0.02787192 0.9721281 ]]
# 2nd bus branch
# predictions : [[6.013328e-04 9.993987e-01]]
# 2nd bus branch
# predictions : [[0.00565095 0.99434906]]
# 2nd bus branch
# predictions : [[0.03704623 0.96295375]]
# 2nd bus branch
# predictions : [[0.04685887 0.9531411 ]]
# 2nd bus branch
# predictions : [[7.8708929e-04 9.9921286e-01]]
# 2nd bus branch
# predictions : [[6.6740386e-04 9.9933261e-01]]
# 2nd bus branch
# predictions : [[0.00583562 0.9941644 ]]
# 2nd bus branch
# predictions : [[2.479413e-04 9.997521e-01]]
# 2nd bus branch
# predictions : [[0.04549014 0.9545099 ]]
# 2nd bus branch
# predictions : [[0.00114114 0.9988588 ]]
# 4900
# 2nd bus branch
# predictions : [[0.00101343 0.99898654]]
# 2nd bus branch
# predictions : [[0.04767495 0.9523251 ]]
# 2nd bus branch
# predictions : [[5.9475360e-04 9.9940526e-01]]
# 2nd bus branch
# predictions : [[0.00258961 0.99741036]]
# 2nd bus branch
# predictions : [[0.00439627 0.9956038 ]]
# 2nd bus branch
# predictions : [[0.00421877 0.9957812 ]]
# 5000
# 5100
# 5200
# 2nd bus branch
# predictions : [[1.8991307e-04 9.9981016e-01]]
# 2nd bus branch
# predictions : [[3.0383136e-04 9.9969625e-01]]
# 5300
# 2nd bus branch
# predictions : [[0.2876137 0.7123863]]
# 2nd bus branch
# predictions : [[0.39892647 0.60107356]]
# 2nd bus branch
# predictions : [[0.00931277 0.9906872 ]]
# 2nd bus branch
# predictions : [[0.47757018 0.5224298 ]]
# 2nd bus branch
# predictions : [[0.3479521 0.6520479]]
# 2nd bus branch
# predictions : [[0.20282088 0.79717916]]
# 2nd bus branch
# predictions : [[0.09419212 0.9058079 ]]
# 2nd bus branch
# predictions : [[0.01034175 0.9896583 ]]
# 2nd bus branch
# predictions : [[0.10251296 0.8974871 ]]
# 2nd bus branch
# predictions : [[0.02263426 0.97736573]]
# 5400
# 2nd bus branch
# predictions : [[0.0154097 0.9845903]]
# 2nd bus branch
# predictions : [[0.10373291 0.89626706]]
# 2nd bus branch
# predictions : [[0.01730524 0.9826948 ]]
# 2nd bus branch
# predictions : [[0.2711672  0.72883284]]
# 2nd bus branch
# predictions : [[0.12748913 0.87251085]]
# 2nd bus branch
# predictions : [[0.05167301 0.94832695]]
# 2nd bus branch
# predictions : [[0.35144973 0.64855033]]
# 2nd bus branch
# predictions : [[0.27150077 0.72849923]]
# 2nd bus branch
# predictions : [[0.35627252 0.6437275 ]]
# 2nd bus branch
# predictions : [[0.15771568 0.8422843 ]]
# 2nd bus branch
# predictions : [[0.05906637 0.94093364]]
# 2nd bus branch
# predictions : [[0.10986853 0.8901315 ]]
# 2nd bus branch
# predictions : [[0.08650413 0.9134959 ]]
# 5500
# 2nd bus branch
# predictions : [[0.01544119 0.98455876]]
# 2nd bus branch
# predictions : [[0.00449734 0.99550265]]
# 5600
# 2nd bus branch
# predictions : [[0.01067475 0.9893253 ]]
# 5700
# 5800
# 2nd bus branch
# predictions : [[0.01489553 0.9851045 ]]
# 5900
# 2nd bus branch
# predictions : [[0.02021674 0.97978324]]
# 2nd bus branch
# predictions : [[0.05743948 0.94256055]]
# 2nd bus branch
# predictions : [[0.01366594 0.986334  ]]
# 2nd bus branch
# predictions : [[0.16738938 0.83261067]]
# 2nd bus branch
# ...
# 2nd bus branch
# predictions : [[0.07999256 0.92000747]]
# 2nd bus branch
# predictions : [[0.1440705 0.8559295]]
# 2nd bus branch
# predictions : [[0.00391374 0.99608624]]
# 2nd bus branch
# predictions : [[0.04227176 0.95772827]]
# 2nd bus branch
# predictions : [[0.14372736 0.8562727 ]]
# 2nd bus branch
# predictions : [[0.00129148 0.9987085 ]]
# 2nd bus branch
# predictions : [[0.00919001 0.99081004]]
# 2nd bus branch
# predictions : [[0.00985935 0.9901406 ]]
# 2nd bus branch
# predictions : [[0.00657561 0.9934244 ]]
# 2nd bus branch
# predictions : [[0.03055715 0.9694428 ]]
# 2nd bus branch
# predictions : [[0.0235547  0.97644526]]
# 2nd bus branch
# predictions : [[0.15360078 0.84639925]]
# 2nd bus branch
# predictions : [[0.04175382 0.95824623]]
# 2nd bus branch
# predictions : [[0.01128154 0.9887185 ]]
# 2nd bus branch
# predictions : [[0.00878237 0.9912176 ]]
# 2nd bus branch
# predictions : [[0.00813032 0.9918697 ]]
# 2nd bus branch
# predictions : [[0.05310525 0.94689476]]
# 2nd bus branch
# predictions : [[0.02108591 0.978914  ]]
# 27500
# 2nd bus branch
# predictions : [[0.0081257 0.9918743]]
# 2nd bus branch
# predictions : [[0.01394244 0.9860576 ]]
# 2nd bus branch
# predictions : [[0.00511627 0.9948837 ]]
# 2nd bus branch
# predictions : [[0.01180773 0.98819226]]
# 2nd bus branch
# predictions : [[0.1195152 0.8804848]]
# 2nd bus branch
# predictions : [[0.08577691 0.914223  ]]
# 2nd bus branch
# predictions : [[0.02669613 0.97330385]]
# 2nd bus branch
# predictions : [[0.048283 0.951717]]
# 2nd bus branch
# predictions : [[0.03409997 0.9659    ]]
# 2nd bus branch
# predictions : [[0.0207639  0.97923607]]
# 2nd bus branch
# predictions : [[0.10243607 0.8975639 ]]
# 2nd bus branch
# predictions : [[0.08570619 0.91429377]]
# 2nd bus branch
# predictions : [[0.10796639 0.8920336 ]]
# 2nd bus branch
# predictions : [[0.01869255 0.9813075 ]]
# 27600
# 2nd bus branch
# predictions : [[0.04378716 0.9562129 ]]
# 2nd bus branch
# predictions : [[0.04521469 0.9547853 ]]
# 2nd bus branch
# predictions : [[0.11914742 0.88085264]]
# 2nd bus branch
# predictions : [[0.01847459 0.9815254 ]]
# 2nd bus branch
# predictions : [[0.04989414 0.95010585]]
# 2nd bus branch
# predictions : [[0.00549989 0.99450004]]
# 2nd bus branch
# predictions : [[0.01381228 0.9861877 ]]
# 2nd bus branch
# predictions : [[0.01878187 0.9812181 ]]
# 2nd bus branch
# predictions : [[0.00962878 0.9903713 ]]
# 2nd bus branch
# predictions : [[0.0058307  0.99416935]]
# 2nd bus branch
# predictions : [[0.0096924  0.99030757]]
# 2nd bus branch
# predictions : [[0.00572542 0.99427456]]
# 2nd bus branch
# predictions : [[0.00330533 0.9966947 ]]
# 2nd bus branch
# predictions : [[0.12137613 0.8786239 ]]
# 2nd bus branch
# predictions : [[0.00928023 0.9907198 ]]
# 2nd bus branch
# predictions : [[0.01288698 0.98711306]]
# 2nd bus branch
# predictions : [[0.01445189 0.9855481 ]]
# 2nd bus branch
# predictions : [[0.02055625 0.9794438 ]]
# 2nd bus branch
# predictions : [[0.08846966 0.9115304 ]]
# 2nd bus branch
# predictions : [[0.0164021  0.98359793]]
# 2nd bus branch
# predictions : [[0.02193864 0.9780613 ]]
# 2nd bus branch
# predictions : [[0.01678299 0.983217  ]]
# 2nd bus branch
# predictions : [[0.02300003 0.977     ]]
# 2nd bus branch
# predictions : [[0.05197661 0.94802344]]
# 2nd bus branch
# predictions : [[0.01031226 0.98968774]]
# 2nd bus branch
# predictions : [[0.00660684 0.9933931 ]]
# 2nd bus branch
# predictions : [[0.01709007 0.98290986]]
# 2nd bus branch
# predictions : [[0.04905401 0.950946  ]]
# 2nd bus branch
# predictions : [[0.00504364 0.9949563 ]]
# 2nd bus branch
# predictions : [[0.01048344 0.98951656]]
# 2nd bus branch
# predictions : [[0.02100358 0.9789964 ]]
# 2nd bus branch
# predictions : [[0.03449278 0.96550727]]
# 2nd bus branch
# predictions : [[0.00645952 0.99354047]]
# 2nd bus branch
# predictions : [[0.01413535 0.98586464]]
# 27700
# 2nd bus branch
# predictions : [[0.02607406 0.9739259 ]]
# 2nd bus branch
# predictions : [[0.04376966 0.95623034]]
# 2nd bus branch
# predictions : [[0.01130181 0.9886982 ]]
# 2nd bus branch
# predictions : [[0.01154171 0.98845834]]
# 2nd bus branch
# predictions : [[0.00734953 0.99265045]]
# 2nd bus branch
# predictions : [[0.03950971 0.9604903 ]]
# 2nd bus branch
# predictions : [[0.02438448 0.97561556]]
# 2nd bus branch
# predictions : [[0.00312526 0.9968747 ]]
# 2nd bus branch
# predictions : [[0.00611439 0.9938856 ]]
# 2nd bus branch
# predictions : [[0.00357638 0.99642354]]
# 2nd bus branch
# predictions : [[0.00513682 0.9948632 ]]
# 2nd bus branch
# predictions : [[0.01419015 0.98580986]]
# 2nd bus branch
# predictions : [[0.0560114  0.94398856]]
# 2nd bus branch
# predictions : [[0.15743873 0.8425613 ]]
# 2nd bus branch
# predictions : [[0.01987777 0.9801222 ]]
# 2nd bus branch
# predictions : [[0.00476601 0.99523395]]
# 2nd bus branch
# predictions : [[0.01084458 0.9891555 ]]
# 2nd bus branch
# predictions : [[0.02320974 0.97679025]]
# 2nd bus branch
# predictions : [[0.01017055 0.9898295 ]]
# 2nd bus branch
# predictions : [[0.02945892 0.9705411 ]]
# 2nd bus branch
# predictions : [[0.02818642 0.97181356]]
# 2nd bus branch
# predictions : [[0.00555046 0.9944495 ]]
# 2nd bus branch
# predictions : [[0.02783235 0.9721676 ]]
# 2nd bus branch
# predictions : [[0.03243407 0.96756595]]
# 2nd bus branch
# predictions : [[0.00634743 0.9936526 ]]
# 2nd bus branch
# predictions : [[0.00696909 0.99303097]]
# 2nd bus branch
# predictions : [[0.24150035 0.7584997 ]]
# 2nd bus branch
# predictions : [[0.09398659 0.9060134 ]]
# 2nd bus branch
# predictions : [[0.0360278 0.9639723]]
# 2nd bus branch
# predictions : [[0.00761504 0.9923849 ]]
# 2nd bus branch
# predictions : [[0.0038708  0.99612916]]
# 2nd bus branch
# predictions : [[0.01079159 0.9892084 ]]
# 2nd bus branch
# predictions : [[4.8537826e-04 9.9951458e-01]]
# 2nd bus branch
# predictions : [[0.00339709 0.9966029 ]]
# 2nd bus branch
# predictions : [[0.01850627 0.9814937 ]]
# 27800
# 2nd bus branch
# predictions : [[0.07623752 0.9237625 ]]
# 2nd bus branch
# predictions : [[0.0045774  0.99542254]]
# 2nd bus branch
# predictions : [[0.01476475 0.9852352 ]]
# 2nd bus branch
# predictions : [[0.16166253 0.8383375 ]]
# 27900
# 2nd bus branch
# predictions : [[0.33936977 0.66063017]]
# 2nd bus branch
# predictions : [[0.03847834 0.9615216 ]]
# 2nd bus branch
# predictions : [[0.00359358 0.9964064 ]]
# 2nd bus branch
# predictions : [[0.01059566 0.9894043 ]]
# 2nd bus branch
# predictions : [[0.05135431 0.94864565]]
# 2nd bus branch
# predictions : [[0.05055462 0.94944537]]
# 2nd bus branch
# predictions : [[0.00230648 0.9976935 ]]
# 2nd bus branch
# predictions : [[0.00622317 0.9937768 ]]
# 2nd bus branch
# predictions : [[0.00698439 0.99301565]]
# 2nd bus branch
# predictions : [[0.00974886 0.9902512 ]]
# 2nd bus branch
# predictions : [[0.00408151 0.9959186 ]]
# 2nd bus branch
# predictions : [[0.15191017 0.8480898 ]]
# 2nd bus branch
# predictions : [[0.00804625 0.9919538 ]]
# 2nd bus branch
# predictions : [[0.00925511 0.9907449 ]]
# 2nd bus branch
# predictions : [[0.04768277 0.9523172 ]]
# 2nd bus branch
# predictions : [[0.05774095 0.942259  ]]
# 2nd bus branch
# predictions : [[0.00627965 0.9937204 ]]
# 2nd bus branch
# predictions : [[0.00541045 0.99458957]]
# 2nd bus branch
# predictions : [[0.00601282 0.9939872 ]]
# 2nd bus branch
# predictions : [[0.00882197 0.991178  ]]
# 2nd bus branch
# predictions : [[0.23249055 0.76750946]]
# 28000
# 2nd bus branch
# predictions : [[0.00676545 0.9932346 ]]
# 2nd bus branch
# predictions : [[0.00849551 0.9915045 ]]
# 2nd bus branch
# predictions : [[0.00454381 0.9954562 ]]
# 2nd bus branch
# predictions : [[0.0020203 0.9979797]]
# 2nd bus branch
# predictions : [[0.03365989 0.9663401 ]]
# 2nd bus branch
# predictions : [[0.06058603 0.93941396]]
# 2nd bus branch
# predictions : [[0.00757628 0.99242365]]
# 2nd bus branch
# predictions : [[0.00232005 0.99768   ]]
# 2nd bus branch
# predictions : [[0.00442147 0.99557847]]
# 2nd bus branch
# predictions : [[0.10921807 0.890782  ]]
# 2nd bus branch
# predictions : [[0.01237887 0.9876211 ]]
# 2nd bus branch
# predictions : [[0.00462199 0.995378  ]]
# 2nd bus branch
# predictions : [[0.00561377 0.9943862 ]]
# 2nd bus branch
# predictions : [[0.00616358 0.99383634]]
# 2nd bus branch
# predictions : [[0.01038602 0.98961395]]
# 2nd bus branch
# predictions : [[0.00309534 0.9969047 ]]
# 2nd bus branch
# predictions : [[0.00130176 0.99869823]]
# 2nd bus branch
# predictions : [[0.01105705 0.988943  ]]
# 2nd bus branch
# predictions : [[0.01074536 0.9892546 ]]
# 2nd bus branch
# predictions : [[0.00778791 0.9922122 ]]
# 2nd bus branch
# predictions : [[0.01269485 0.9873052 ]]
# 2nd bus branch
# predictions : [[0.00593919 0.9940608 ]]
# 2nd bus branch
# predictions : [[0.00628499 0.993715  ]]
# 2nd bus branch
# predictions : [[0.00530453 0.9946955 ]]
# 2nd bus branch
# predictions : [[0.00384839 0.9961516 ]]
# 2nd bus branch
# predictions : [[0.01441756 0.9855825 ]]
# 2nd bus branch
# predictions : [[0.00454936 0.9954507 ]]
# 2nd bus branch
# predictions : [[0.02211995 0.97788006]]
# 2nd bus branch
# predictions : [[0.0054515 0.9945485]]
# 2nd bus branch
# predictions : [[0.00419157 0.9958085 ]]
# 2nd bus branch
# predictions : [[0.07954099 0.92045903]]
# 2nd bus branch
# predictions : [[0.0401963  0.95980376]]
# 2nd bus branch
# predictions : [[0.00489702 0.995103  ]]
# 2nd bus branch
# predictions : [[0.01496479 0.9850352 ]]
# 2nd bus branch
# predictions : [[0.07897231 0.9210277 ]]
# 2nd bus branch
# predictions : [[0.05103964 0.9489603 ]]
# 2nd bus branch
# predictions : [[0.0351238  0.96487623]]
# 2nd bus branch
# predictions : [[0.04568014 0.95431983]]
# 2nd bus branch
# predictions : [[0.02880966 0.97119033]]
# 2nd bus branch
# predictions : [[0.0058015  0.99419856]]
# 2nd bus branch
# predictions : [[0.35269734 0.6473026 ]]
# 2nd bus branch
# predictions : [[0.24034664 0.75965333]]
# 28100
# 2nd bus branch
# predictions : [[0.37071884 0.62928116]]
# 2nd bus branch
# predictions : [[0.01657664 0.98342335]]
# 2nd bus branch
# predictions : [[0.0267934  0.97320664]]
# 2nd bus branch
# predictions : [[0.00715408 0.99284595]]
# 2nd bus branch
# predictions : [[0.01090246 0.9890975 ]]
# 2nd bus branch
# predictions : [[0.01104021 0.9889598 ]]
# 2nd bus branch
# predictions : [[0.01155864 0.98844135]]
# 2nd bus branch
# predictions : [[0.00828436 0.9917156 ]]
# 2nd bus branch
# predictions : [[0.01615337 0.98384666]]
# 2nd bus branch
# predictions : [[0.0405713 0.9594288]]
# 2nd bus branch
# predictions : [[0.05868085 0.94131917]]
# 2nd bus branch
# predictions : [[0.02842895 0.9715711 ]]
# 2nd bus branch
# predictions : [[0.04306633 0.9569337 ]]
# 2nd bus branch
# predictions : [[0.00648862 0.9935114 ]]
# 2nd bus branch
# predictions : [[0.04549996 0.9545    ]]
# 2nd bus branch
# predictions : [[0.01954851 0.9804515 ]]
# 2nd bus branch
# predictions : [[0.00185662 0.99814343]]
# 2nd bus branch
# predictions : [[0.03377114 0.9662289 ]]
# 2nd bus branch
# predictions : [[0.00477357 0.9952264 ]]
# 2nd bus branch
# predictions : [[0.00946495 0.9905351 ]]
# 2nd bus branch
# predictions : [[0.00971473 0.9902852 ]]
# 2nd bus branch
# predictions : [[0.01803728 0.98196274]]
# 2nd bus branch
# predictions : [[0.01013773 0.9898623 ]]
# 2nd bus branch
# predictions : [[0.00450373 0.9954963 ]]
# 2nd bus branch
# predictions : [[0.04458904 0.955411  ]]
# 2nd bus branch
# predictions : [[0.00105575 0.9989442 ]]
# 2nd bus branch
# predictions : [[0.00648427 0.99351573]]
# 2nd bus branch
# predictions : [[0.00116728 0.99883276]]
# 2nd bus branch
# predictions : [[0.00242955 0.99757046]]
# 2nd bus branch
# predictions : [[0.00498721 0.9950128 ]]
# 2nd bus branch
# predictions : [[0.00555803 0.9944419 ]]
# 2nd bus branch
# predictions : [[0.00306283 0.99693716]]
# 2nd bus branch
# predictions : [[0.0084655  0.99153453]]
# 2nd bus branch
# predictions : [[0.00339849 0.99660146]]
# 2nd bus branch
# predictions : [[0.0048656 0.9951344]]
# 2nd bus branch
# predictions : [[0.00342283 0.9965772 ]]
# 2nd bus branch
# predictions : [[0.01205779 0.98794216]]
# 2nd bus branch
# predictions : [[0.00750117 0.9924988 ]]
# 2nd bus branch
# predictions : [[0.02444796 0.975552  ]]
# 2nd bus branch
# predictions : [[0.01091118 0.98908883]]
# 28200
# 2nd bus branch
# predictions : [[0.00535956 0.9946404 ]]
# 2nd bus branch
# predictions : [[0.01091329 0.98908675]]
# 2nd bus branch
# predictions : [[0.01094478 0.9890553 ]]
# 2nd bus branch
# predictions : [[0.02305814 0.9769419 ]]
# 2nd bus branch
# predictions : [[0.09433739 0.90566266]]
# 2nd bus branch
# predictions : [[0.00518173 0.9948183 ]]
# 2nd bus branch
# predictions : [[0.00746991 0.99253005]]
# 2nd bus branch
# predictions : [[0.00749583 0.99250424]]
# 2nd bus branch
# predictions : [[0.00610208 0.993898  ]]
# 2nd bus branch
# predictions : [[0.0048578 0.9951422]]
# 2nd bus branch
# predictions : [[0.00255023 0.9974497 ]]
# 2nd bus branch
# predictions : [[0.00275956 0.9972404 ]]
# 2nd bus branch
# predictions : [[0.00381932 0.99618065]]
# 2nd bus branch
# predictions : [[0.01619452 0.9838054 ]]
# 2nd bus branch
# predictions : [[0.01134241 0.98865753]]
# 2nd bus branch
# predictions : [[0.00415119 0.9958488 ]]
# 2nd bus branch
# predictions : [[0.0128159 0.9871841]]
# 2nd bus branch
# predictions : [[0.00522666 0.9947733 ]]
# 2nd bus branch
# predictions : [[0.01402713 0.9859729 ]]
# 2nd bus branch
# predictions : [[0.00445998 0.99553996]]
# 2nd bus branch
# predictions : [[0.00646643 0.9935336 ]]
# 2nd bus branch
# predictions : [[0.01422456 0.9857755 ]]
# 2nd bus branch
# predictions : [[0.00738712 0.99261284]]
# 2nd bus branch
# predictions : [[0.00310748 0.9968925 ]]
# 2nd bus branch
# predictions : [[0.00436858 0.99563146]]
# 2nd bus branch
# predictions : [[0.00648859 0.9935114 ]]
# 2nd bus branch
# predictions : [[0.02672008 0.9732799 ]]
# 2nd bus branch
# predictions : [[0.00900241 0.99099755]]
# 2nd bus branch
# predictions : [[0.01330677 0.9866932 ]]
# 2nd bus branch
# predictions : [[0.01429793 0.98570204]]
# 2nd bus branch
# predictions : [[0.00289914 0.9971008 ]]
# 2nd bus branch
# predictions : [[0.00358146 0.9964186 ]]
# 2nd bus branch
# predictions : [[0.17695263 0.82304734]]
# 2nd bus branch
# predictions : [[0.00234813 0.9976519 ]]
# 2nd bus branch
# predictions : [[0.0105488 0.9894512]]
# 2nd bus branch
# predictions : [[0.13849998 0.86149997]]
# 2nd bus branch
# predictions : [[0.02960677 0.97039324]]
# 2nd bus branch
# predictions : [[0.0149952 0.9850048]]
# 2nd bus branch
# predictions : [[0.03044736 0.96955264]]
# 2nd bus branch
# predictions : [[0.00391243 0.99608755]]
# 2nd bus branch
# predictions : [[0.00374613 0.99625385]]
# 28300
# 2nd bus branch
# predictions : [[0.00640786 0.9935921 ]]
# 2nd bus branch
# predictions : [[0.02667742 0.9733226 ]]
# 2nd bus branch
# predictions : [[0.01987873 0.98012125]]
# 2nd bus branch
# predictions : [[0.10491794 0.89508206]]
# 2nd bus branch
# predictions : [[0.12917206 0.8708279 ]]
# 2nd bus branch
# predictions : [[0.00508541 0.99491453]]
# 2nd bus branch
# predictions : [[0.00286287 0.9971372 ]]
# 2nd bus branch
# predictions : [[0.00580003 0.9942    ]]
# 2nd bus branch
# predictions : [[0.11787545 0.8821245 ]]
# 2nd bus branch
# predictions : [[0.01757587 0.9824241 ]]
# 2nd bus branch
# predictions : [[0.1817709 0.8182291]]
# 28400
# 2nd bus branch
# predictions : [[0.02977659 0.9702234 ]]
# 28500
# 2nd bus branch
# predictions : [[0.04256794 0.95743203]]
# 2nd bus branch
# predictions : [[0.405499   0.59450096]]
# 2nd bus branch
# predictions : [[0.3885352  0.61146474]]
# 2nd bus branch
# predictions : [[0.3521077 0.6478923]]
# 2nd bus branch
# predictions : [[0.15589404 0.844106  ]]
# 2nd bus branch
# predictions : [[0.27132878 0.72867125]]
# 2nd bus branch
# predictions : [[0.48961958 0.51038045]]
# 2nd bus branch
# predictions : [[0.07709644 0.92290354]]
# 2nd bus branch
# predictions : [[0.03308421 0.96691585]]
# 28600
# 2nd bus branch
# predictions : [[0.08355095 0.916449  ]]
# 2nd bus branch
# predictions : [[0.0056302 0.9943698]]
# 2nd bus branch
# predictions : [[0.01364047 0.98635954]]
# 2nd bus branch
# predictions : [[0.00510339 0.9948966 ]]
# 2nd bus branch
# predictions : [[0.00618929 0.9938107 ]]
# 2nd bus branch
# predictions : [[0.00725077 0.9927492 ]]
# 2nd bus branch
# predictions : [[0.00471202 0.995288  ]]
# 2nd bus branch
# predictions : [[0.00820479 0.99179524]]
# 2nd bus branch
# predictions : [[0.01435278 0.9856472 ]]
# 2nd bus branch
# predictions : [[0.00218956 0.9978104 ]]
# 2nd bus branch
# predictions : [[0.00298019 0.9970198 ]]
# 2nd bus branch
# predictions : [[7.824584e-04 9.992175e-01]]
# 2nd bus branch
# predictions : [[0.15107988 0.84892017]]
# 28700
# 2nd bus branch
# predictions : [[0.00272993 0.99727005]]
# 2nd bus branch
# predictions : [[5.6984625e-04 9.9943012e-01]]
# 2nd bus branch
# predictions : [[0.00249579 0.9975042 ]]
# 2nd bus branch
# predictions : [[0.06269187 0.93730813]]
# 2nd bus branch
# predictions : [[0.00371079 0.99628925]]
# 2nd bus branch
# predictions : [[0.07781747 0.92218256]]
# --- 8169.508459806442 seconds ---

# %%
print(np.bincount(y_true))
print(np.bincount(y_pred_class-1))
# Out:
# [5964 5230  555 2406 4094 1836 4362 4342]
# [5540 4687  478 1605 3033 5119 3715 4612]

# %%
# confusion matrix
import matplotlib.pyplot as plt
import sklearn.metrics
import seaborn as sn

labels = ['Still', 'Walk', 'Run', 'Bike', 'Car', 'Bus', 'Train', 'Subway']

def plot_confusion_matrix(y_true, y_pred_class):
    fig, ax = plt.subplots(figsize=(10,8))
    confusion_mat = sklearn.metrics.confusion_matrix(y_true, y_pred_class-1)
    sn.heatmap(confusion_mat, cmap="YlGnBu", annot=True, annot_kws={"size": 8})
    ax.xaxis.set_ticklabels(labels);
    ax.yaxis.set_ticklabels(labels);
    plt.savefig('confusion_matrix_{}.svg'.format(checkpoint_path), format='svg')
    plt.show()

# %%
print('accuracy = {}'.format(sklearn.metrics.accuracy_score(y_true, y_pred_class-1)))
print('f1 score = {}'.format(sklearn.metrics.f1_score(y_true, y_pred_class-1, average='macro')))
plot_confusion_matrix(y_true, y_pred_class)
# Out:
# accuracy = 0.7045746639341415
# f1 score = 0.7110383478367015

# %%
true_still = np.argwhere(y_true == 1)[:, 0]
predicted_train = np.argwhere(y_pred_class == 7)[:, 0]

# %%
print(true_still)
# Out:
# [   58    59    60 ... 28786 28787 28788]

# %%
print(predicted_train)
# Out:
# [  795   818   820 ... 28592 28596 28598]

# %%
confused = []
for still in true_still:
    for train in predicted_train:
        if still == train:
            confused.append(still)
            print('{} = {}'.format(still, train))
# Out:
# 1811 = 1811
# 3371 = 3371
# 3409 = 3409
# 3478 = 3478
# 5255 = 5255
# 8934 = 8934
# 12645 = 12645
# 20487 = 20487
# 20490 = 20490
# 20840 = 20840
# 20843 = 20843
# 20845 = 20845
# 23601 = 23601
# 25140 = 25140
# 25278 = 25278
# 26199 = 26199
# 26201 = 26201
# 26203 = 26203
# 27800 = 27800
# 27924 = 27924
# 27926 = 27926

# %%
print(len(confused))
# Out:
# 21
